# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Read the datasets

# %%
import pandas
ha_df = pandas.read_csv("/content/drive/My Drive/datasets/ha.csv")
hb_df = pandas.read_csv("/content/drive/My Drive/datasets/hb.csv")
hc_df = pandas.read_csv("/content/drive/My Drive/datasets/hc.csv")
hd_df = pandas.read_csv("/content/drive/My Drive/datasets/hd.csv")

# %%
ha_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1923 entries, 0 to 1922
# Columns: 145 entries, AGE to FETUS1MECONIUMASPIRATIONSYNDROME
# dtypes: float64(13), int64(8), object(124)
# memory usage: 2.1+ MB

# %%
hb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 893 entries, 0 to 892
# Columns: 145 entries, AGE to FETUS1MECONIUMASPIRATIONSYNDROME
# dtypes: float64(38), int64(9), object(98)
# memory usage: 1011.7+ KB

# %%
hc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2458 entries, 0 to 2457
# Columns: 145 entries, AGE to FETUS1MECONIUMASPIRATIONSYNDROME
# dtypes: float64(22), int64(9), object(114)
# memory usage: 2.7+ MB

# %%
hd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 883 entries, 0 to 882
# Columns: 145 entries, AGE to FETUS1MECONIUMASPIRATIONSYNDROME
# dtypes: float64(42), int64(13), object(90)
# memory usage: 1000.4+ KB

# %% [markdown]
# ### Concatenating the datasets

# %%
c_df = pandas.concat([ha_df, hb_df, hc_df, hd_df], ignore_index=True)
c_df
# Out:
#       AGE COUPLESITUATION  HEIGHT  WEIGHT    BMI COUNTRYOFORIGYN  \
# 0      30      withcouple    1.58    70.0  28.04           CHILE
# 1      38      withcouple    1.61    79.0  30.48          ESPAÑA
# 2      25      withcouple    1.56    72.0  29.59        COLOMBIA
# 3      31      withcouple    1.62    54.0  20.58          ESPAÑA
# 4      28      withcouple    1.47    51.0  23.60          ESPAÑA
# ...   ...             ...     ...     ...    ...             ...
# 6152   35      withcouple    1.56    49.0  20.00          ESPAÑA
# 6153   29      withcouple    1.64    59.0  21.51          ESPAÑA
# 6154   39      withcouple    1.59    64.0  20.00          ESPAÑA
# 6155   41      withcouple    1.48    50.0  23.28          ESPAÑA
# 6156   32      withcouple    1.65    75.2  24.00         ARGELIA
#
#      MATERNALEDUCATION STARTANTENATALCARRE SUBSTANCEABUSE SMOKING  ...  \
# 0            secondary         1ºtrimester              f       f  ...
# 1            secondary         1ºtrimester              f       f  ...
# 2            secondary         1ºtrimester              f       f  ...
# 3            secondary         1ºtrimester              f       f  ...
# 4            secondary         1ºtrimester              f       f  ...
# ...                ...                 ...            ...     ...  ...
# 6152         secondary         1ºtrimester              f       f  ...
# 6153         secondary         1ºtrimester              f       f  ...
# 6154         secondary         1ºtrimester              f       f  ...
# 6155           primary         1ºtrimester              f       f  ...
# 6156       Sinestudios         1ºtrimester              f       f  ...
#
#       HEMATOMALDRAINAGE INTRAPARTUMpHvalue  sexfetus1  weightfetus1  \
# 0                   NaN                NaN  Masculino          2640
# 1                   NaN                NaN   Femenino          3040
# 2                   NaN                NaN   Femenino          3820
# 3                   NaN                NaN   Femenino          3390
# 4                   NaN                NaN  Masculino          3020
# ...                 ...                ...        ...           ...
# 6152               1960                 10         10          7.27
# 6153               3310                  9         10   DESCONOCIDO
# 6154               3830                  8          9   DESCONOCIDO
# 6155               2810                 10         10   DESCONOCIDO
# 6156               3160                 10         10   DESCONOCIDO
#
#      apgarfetus1 apgarfetus1fivemin pHvaluefetus1umbilicalarthery  \
# 0              7                  9                          7.34
# 1              8                  9                          7.26
# 2             10                 10                          7.21
# 3              9                 10                          7.21
# 4              8                  9                          7.17
# ...          ...                ...                           ...
# 6152           f                NaN                             f
# 6153           f                NaN                             f
# 6154           f                NaN                             f
# 6155           f                NaN                             f
# 6156           f                NaN                             f
#
#      FETUS1ADMISSIONICU            FETUS1RECOVERY  \
# 0                     f  1:Aspiraciónnasofaríngea
# 1                     f               0:noprecisa
# 2                     f               0:noprecisa
# 3                     f               0:noprecisa
# 4                     f               0:noprecisa
# ...                 ...                       ...
# 6152                NaN                       NaN
# 6153                NaN                       NaN
# 6154                NaN                       NaN
# 6155                NaN                       NaN
# 6156                NaN                       NaN
#
#      FETUS1MECONIUMASPIRATIONSYNDROME
# 0                                   f
# 1                                   f
# 2                                   f
# 3                                   f
# 4                                   f
# ...                               ...
# 6152                              NaN
# 6153                              NaN
# 6154                              NaN
# 6155                              NaN
# 6156                              NaN
#
# [6157 rows x 145 columns]

# %% [markdown]
# ### Information of the concatenated dataset

# %%
c_df.info(145)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6157 entries, 0 to 6156
# Data columns (total 145 columns):
#  #    Column                                  Dtype
# ---   ------                                  -----
#  0    AGE                                     int64
#  1    COUPLESITUATION                         object
#  2    HEIGHT                                  float64
#  3    WEIGHT                                  float64
#  4    BMI                                     float64
#  5    COUNTRYOFORIGYN                         object
#  6    MATERNALEDUCATION                       object
#  7    STARTANTENATALCARRE                     object
#  8    SUBSTANCEABUSE                          object
#  9    SMOKING                                 object
#  10   CIGARRETTESPERDAY                       float64
#  11   ALCOHOL                                 object
#  12   DAILYALCOHOLINTAKE                      object
#  13   KGINCREASEDPREGNANCY                    int64
#  14   ART                                     object
#  15   ARTMODE                                 object
#  16   AMNIOCENTESIS                           object
#  17   PREVIOUSCESAREAN                        object
#  18   NUMBEROFPREVCESAREAN                    float64
#  19   COMORBIDITY                             object
#  20   OBSTETRICRISK                           object
#  21   PREVIOUSTERMPREGNANCIES                 int64
#  22   PREVIOUSPRETERMPREGNANCIES              int64
#  23   MISCARRIAGES                            int64
#  24   ALIVENEWBORNS                           int64
#  25   PARITY                                  int64
#  26   PREINDUCTION                            object
#  27   INDUCTION                               object
#  28   HOURSROMBEFOREINDUCTION                 object
#  29   ANESTHESIA                              object
#  30   HOURSOFRUPTUREDMEMBRANESATDELIVERY      object
#  31   GESTAGIONALAGE                          int64
#  32   CARDIOTOCOGRAPHY                        object
#  33   TYPEOFBIRTH                             object
#  34   EPISIOTOMY                              object
#  35   TEAR                                    object
#  36   MEDICALINDICATION                       object
#  37   EMERGENCYCESAREANSECTION                object
#  38   PROGRAMMEDCESAREANSECTION               object
#  39   OXYTOCIN                                object
#  40   AMNIOTICLIQUID                          object
#  41   FetalINTRAPARTUMpH                      object
#  42   COMPLICATIONS                           object
#  43   ROBSONGROUP                             object
#  44   CESAREANINACCORDANCETOCLINICALSTANDARD  object
#  45   COLESTASISGRAVIDICA                     object
#  46   CORIONAMNIONITIS                        object
#  47   NONIDGESTATIONALDIABETES                object
#  48   IDGESTATIONALDIABETES                   object
#  49   PROLONGEDPREGNANACY                     object
#  50   MULTIPLEGESTATION                       object
#  51   HELLP                                   object
#  52   GESTATIONALHYPERTENSION                 object
#  53   ISOINMUNIZACION                         object
#  54   STAINEDAMNIOTICLIQUOR                   object
#  55   FETALMALFORMATION                       object
#  56   UTERINEMALFORMATION                     object
#  57   FETALMALPOSITION                        object
#  58   MIOMECTOMY                              object
#  59   OLIGOAMNIOS                             object
#  60   PREVIOUSPRETERMDELIVERY                 object
#  61   PLACENTAPREVIA                          object
#  62   POLIHIDRAMNIOS                          object
#  63   SEVEREPREECLAMPSIA                      object
#  64   MILDPREECLAMPSIA                        object
#  65   PROM                                    object
#  66   SIFILIS                                 object
#  67   TOXOPLASMOSIS                           object
#  68   REPEATEDMISCARRIAGES                    object
#  69   PREVIOUSFETALLOSSES                     object
#  70   ANTEPARTUMLOSSOFFETALWELLBEEING         object
#  71   MATERNALANEMIA                          object
#  72   ASTHMA                                  object
#  73   CARDIACDISEASE                          object
#  74   Coagulopathy                            object
#  75   PREGESTATIONALTYPEIDIABETES             object
#  76   PREGESTATIONALTYPEIIDIABETES            object
#  77   AUTOINMUNEDISEASEINTREATMENT            object
#  78   EPILEPSYINTREATMENT                     object
#  79   MENTALDISEASEINTREATMENT                object
#  80   NEUROLOGICALDISEASEINTREATMENT          object
#  81   RENALDISEASEINTREATMENT                 object
#  82   Hemiplegia                              object
#  83   LIVERDISEASEINTREATMENT                 object
#  84   HIPERTHYROIDISMINTREATMENT              object
#  85   HIPOTHYROIDISMINTREATMENT               object
#  86   HIV+                                    object
#  87   CHRONICHYPERTENSION                     object
#  88   TIP                                     object
#  89   MALIGNANTTUMOR                          object
#  90   HVC+                                    object
#  91   HVB+                                    object
#  92   CORIONICBIOPSY                          object
#  93   Cordocentesis                           float64
#  94   Cannabis                                object
#  95   COCCAINE                                object
#  96   Heroin                                  object
#  97   others                                  object
#  98   IUGR                                    object
#  99   Colestasis                              object
#  100  Diabetes                                object
#  101  ABNORMALDOPPLER                         object
#  102  ExitusFetal                             object
#  103  STAINEDAMNIOTICLIQUID                   object
#  104  NONCONFIDENTNST                         object
#  105  Oligoamnios                             object
#  106  MATERNALDISEASE                         object
#  107  SGD                                     object
#  108  Preeclampsia                            object
#  109  PROM.1                                  object
#  110  INITIALPROLONGEDPREGNANCY               object
#  111  OTHERS                                  object
#  112  LOC                                     object
#  113  REG                                     object
#  114  GEN                                     object
#  115  UTERINEATONY                            object
#  116  AMNIOTICLIQUIDEMBOLISM                  float64
#  117  PERINEALHEMATOMA                        object
#  118  UTERINEHAEMORRAGE                       object
#  119  INVERTEDUTERUS                          object
#  120  MATERNALDEATH                           object
#  121  RETAINEDPLACENTA                        object
#  122  UTERINERUPTURE                          object
#  123  PULMONARTHROMBOEMBOLISM                 object
#  124  DEEPVENOUSTHROMBOSIS                    object
#  125  SHOULDERDYSTOCIA                        object
#  126  TEARREPAIR                              object
#  127  MANUALEXTRACTIONOFPLACENTA              object
#  128  HISTERECTOMY                            object
#  129  POSTPARTUMCURETAGE                      object
#  130  REPOSITIONOFINVERTEDUTERUS              object
#  131  BLOODTRANSFUSION                        object
#  132  MEDICALTREATMENT                        object
#  133  MANUALASSITANCETOSHOULDERDYSTOCIA       object
#  134  ARTHERIALEMBOLIZATION                   object
#  135  HEMATOMALDRAINAGE                       object
#  136  INTRAPARTUMpHvalue                      object
#  137  sexfetus1                               object
#  138  weightfetus1                            object
#  139  apgarfetus1                             object
#  140  apgarfetus1fivemin                      object
#  141  pHvaluefetus1umbilicalarthery           object
#  142  FETUS1ADMISSIONICU                      object
#  143  FETUS1RECOVERY                          object
#  144  FETUS1MECONIUMASPIRATIONSYNDROME        object
# dtypes: float64(7), int64(8), object(130)
# memory usage: 6.8+ MB

# %% [markdown]
# ### Checking missing values

# %%
c_df.isnull().sum()
# Out:
# AGE                                    0
# COUPLESITUATION                        0
# HEIGHT                                 0
# WEIGHT                                 0
# BMI                                    0
#                                     ...
# apgarfetus1fivemin                  4219
# pHvaluefetus1umbilicalarthery          0
# FETUS1ADMISSIONICU                  4238
# FETUS1RECOVERY                      4235
# FETUS1MECONIUMASPIRATIONSYNDROME    4234
# Length: 145, dtype: int64

# %% [markdown]
# ### Class labels

# %%
c_df.TYPEOFBIRTH.unique()
# Out:
# array(['emergencyc-section', 'CESprogrammed', 'EUT', 'vacum', 'FORC',
#        'ESP', 'NALGASVAGINAL'], dtype=object)

# %%
a = c_df['TYPEOFBIRTH'].values.tolist()
s = set(a)
for x in s:
  print(x,":",a.count(x))
# Out:
# EUT : 4231
# emergencyc-section : 692
# CESprogrammed : 325
# FORC : 87
# ESP : 44
# NALGASVAGINAL : 8
# vacum : 770

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# ### Dataset after feature extraction

# %%
new_df = c_df[['PREVIOUSCESAREAN','COMPLICATIONS','ROBSONGROUP','ARTMODE','PREVIOUSPRETERMPREGNANCIES','AMNIOCENTESIS','PREINDUCTION','INDUCTION',
        'PARITY','OBSTETRICRISK','COMORBIDITY','NUMBEROFPREVCESAREAN','KGINCREASEDPREGNANCY','STARTANTENATALCARRE',
        'ART','PREVIOUSTERMPREGNANCIES','AMNIOTICLIQUID','MISCARRIAGES','ANESTHESIA','EPISIOTOMY','OXYTOCIN','FetalINTRAPARTUMpH',
        'GESTAGIONALAGE','HEIGHT','WEIGHT','BMI','AGE','CARDIOTOCOGRAPHY','MATERNALEDUCATION','SUBSTANCEABUSE','SMOKING','ALCOHOL','TYPEOFBIRTH']]

# %% [markdown]
# ### Checking duplicates

# %%
new_df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6152    False
# 6153    False
# 6154    False
# 6155    False
# 6156    False
# Length: 6157, dtype: bool

# %%
new_df.duplicated().sum()
# Out:
# 17

# %% [markdown]
# ### Drop duplicate records

# %%
new_df1 = new_df.drop_duplicates()
new_df1
# Out:
#      PREVIOUSCESAREAN COMPLICATIONS ROBSONGROUP ARTMODE  \
# 0                   f             f     group2a     NaN
# 1                   f             f      group6     NaN
# 2                   f             f      group1     NaN
# 3                   t             f      group5     NaN
# 4                   f             f      group1     FIV
# ...               ...           ...         ...     ...
# 6152                f             f      group8     NaN
# 6153                f             f      group3     NaN
# 6154                f             f      group1     IAD
# 6155                f             f     group2a     FIV
# 6156                f             f      group3     NaN
#
#       PREVIOUSPRETERMPREGNANCIES AMNIOCENTESIS PREINDUCTION INDUCTION  PARITY  \
# 0                              0             f            t         t       0
# 1                              0             f            f         f      10
# 2                              0             f            f         f      10
# 3                              0             f            f         f    1001
# 4                              0             f            f         f      10
# ...                          ...           ...          ...       ...     ...
# 6152                           0             t            f         f       0
# 6153                           0             f            f         f    1001
# 6154                           0             f            f         f      20
# 6155                           0             f            f         t    1020
# 6156                           0             f            f         f    2002
#
#      OBSTETRICRISK  ... HEIGHT  WEIGHT    BMI AGE CARDIOTOCOGRAPHY  \
# 0                t  ...   1.58    70.0  28.04  30       continuous
# 1                f  ...   1.61    79.0  30.48  38       continuous
# 2                f  ...   1.56    72.0  29.59  25       continuous
# 3                t  ...   1.62    54.0  20.58  31       continuous
# 4                f  ...   1.47    51.0  23.60  28       continuous
# ...            ...  ...    ...     ...    ...  ..              ...
# 6152             t  ...   1.56    49.0  20.00  35       continuous
# 6153             f  ...   1.64    59.0  21.51  29       continuous
# 6154             f  ...   1.59    64.0  20.00  39    discontinuous
# 6155             t  ...   1.48    50.0  23.28  41       continuous
# 6156             f  ...   1.65    75.2  24.00  32    discontinuous
#
#       MATERNALEDUCATION SUBSTANCEABUSE  SMOKING ALCOHOL         TYPEOFBIRTH
# 0             secondary              f        f       f  emergencyc-section
# 1             secondary              f        f       f       CESprogrammed
# 2             secondary              f        f       f                 EUT
# 3             secondary              f        f       f                 EUT
# 4             secondary              f        f       f                 EUT
# ...                 ...            ...      ...     ...                 ...
# 6152          secondary              f        f       f                 EUT
# 6153          secondary              f        f       f                 EUT
# 6154          secondary              f        f       t                 EUT
# 6155            primary              f        f       f  emergencyc-section
# 6156        Sinestudios              f        f       f                 EUT
#
# [6140 rows x 33 columns]

# %%
import numpy as np
new_df1 = new_df1.replace(r'^\s*$', np.nan, regex=True)

# %% [markdown]
# ### Handling missing values of categorical attributes by mode

# %%
s = (new_df1.dtypes == 'object')
#print(s)
#print(s[s])
object_cols = list(s[s].index)
print("Categorical variables:")
print(object_cols)
print(len(object_cols))
# Out:
# Categorical variables:
# ['PREVIOUSCESAREAN', 'COMPLICATIONS', 'ROBSONGROUP', 'ARTMODE', 'AMNIOCENTESIS', 'PREINDUCTION', 'INDUCTION', 'OBSTETRICRISK', 'COMORBIDITY', 'STARTANTENATALCARRE', 'ART', 'AMNIOTICLIQUID', 'ANESTHESIA', 'EPISIOTOMY', 'OXYTOCIN', 'FetalINTRAPARTUMpH', 'CARDIOTOCOGRAPHY', 'MATERNALEDUCATION', 'SUBSTANCEABUSE', 'SMOKING', 'ALCOHOL', 'TYPEOFBIRTH']
# 22

# %%
for i in object_cols:
  x = new_df1[i].mode()[0]
  new_df1[i].fillna(x,inplace = True)
new_df1
# Out:
#      PREVIOUSCESAREAN COMPLICATIONS ROBSONGROUP ARTMODE  \
# 0                   f             f     group2a     FIV
# 1                   f             f      group6     FIV
# 2                   f             f      group1     FIV
# 3                   t             f      group5     FIV
# 4                   f             f      group1     FIV
# ...               ...           ...         ...     ...
# 6152                f             f      group8     FIV
# 6153                f             f      group3     FIV
# 6154                f             f      group1     IAD
# 6155                f             f     group2a     FIV
# 6156                f             f      group3     FIV
#
#       PREVIOUSPRETERMPREGNANCIES AMNIOCENTESIS PREINDUCTION INDUCTION  PARITY  \
# 0                              0             f            t         t       0
# 1                              0             f            f         f      10
# 2                              0             f            f         f      10
# 3                              0             f            f         f    1001
# 4                              0             f            f         f      10
# ...                          ...           ...          ...       ...     ...
# 6152                           0             t            f         f       0
# 6153                           0             f            f         f    1001
# 6154                           0             f            f         f      20
# 6155                           0             f            f         t    1020
# 6156                           0             f            f         f    2002
#
#      OBSTETRICRISK  ... HEIGHT  WEIGHT    BMI AGE CARDIOTOCOGRAPHY  \
# 0                t  ...   1.58    70.0  28.04  30       continuous
# 1                f  ...   1.61    79.0  30.48  38       continuous
# 2                f  ...   1.56    72.0  29.59  25       continuous
# 3                t  ...   1.62    54.0  20.58  31       continuous
# 4                f  ...   1.47    51.0  23.60  28       continuous
# ...            ...  ...    ...     ...    ...  ..              ...
# 6152             t  ...   1.56    49.0  20.00  35       continuous
# 6153             f  ...   1.64    59.0  21.51  29       continuous
# 6154             f  ...   1.59    64.0  20.00  39    discontinuous
# 6155             t  ...   1.48    50.0  23.28  41       continuous
# 6156             f  ...   1.65    75.2  24.00  32    discontinuous
#
#       MATERNALEDUCATION SUBSTANCEABUSE  SMOKING ALCOHOL         TYPEOFBIRTH
# 0             secondary              f        f       f  emergencyc-section
# 1             secondary              f        f       f       CESprogrammed
# 2             secondary              f        f       f                 EUT
# 3             secondary              f        f       f                 EUT
# 4             secondary              f        f       f                 EUT
# ...                 ...            ...      ...     ...                 ...
# 6152          secondary              f        f       f                 EUT
# 6153          secondary              f        f       f                 EUT
# 6154          secondary              f        f       t                 EUT
# 6155            primary              f        f       f  emergencyc-section
# 6156        Sinestudios              f        f       f                 EUT
#
# [6140 rows x 33 columns]

# %% [markdown]
# ### Handling missing values of Numerical attributes using mean

# %%
s = (new_df1.dtypes != 'object')
number_cols = list(s[s].index)
print("Numerical variables:")
print(number_cols)
print(len(number_cols))
# Out:
# Numerical variables:
# ['PREVIOUSPRETERMPREGNANCIES', 'PARITY', 'NUMBEROFPREVCESAREAN', 'KGINCREASEDPREGNANCY', 'PREVIOUSTERMPREGNANCIES', 'MISCARRIAGES', 'GESTAGIONALAGE', 'HEIGHT', 'WEIGHT', 'BMI', 'AGE']
# 11

# %%
for i in number_cols:
  x = new_df1[i].mean()
  new_df1[i].fillna(x,inplace = True)
new_df1
# Out:
#      PREVIOUSCESAREAN COMPLICATIONS ROBSONGROUP ARTMODE  \
# 0                   f             f     group2a     FIV
# 1                   f             f      group6     FIV
# 2                   f             f      group1     FIV
# 3                   t             f      group5     FIV
# 4                   f             f      group1     FIV
# ...               ...           ...         ...     ...
# 6152                f             f      group8     FIV
# 6153                f             f      group3     FIV
# 6154                f             f      group1     IAD
# 6155                f             f     group2a     FIV
# 6156                f             f      group3     FIV
#
#       PREVIOUSPRETERMPREGNANCIES AMNIOCENTESIS PREINDUCTION INDUCTION  PARITY  \
# 0                              0             f            t         t       0
# 1                              0             f            f         f      10
# 2                              0             f            f         f      10
# 3                              0             f            f         f    1001
# 4                              0             f            f         f      10
# ...                          ...           ...          ...       ...     ...
# 6152                           0             t            f         f       0
# 6153                           0             f            f         f    1001
# 6154                           0             f            f         f      20
# 6155                           0             f            f         t    1020
# 6156                           0             f            f         f    2002
#
#      OBSTETRICRISK  ... HEIGHT  WEIGHT    BMI AGE CARDIOTOCOGRAPHY  \
# 0                t  ...   1.58    70.0  28.04  30       continuous
# 1                f  ...   1.61    79.0  30.48  38       continuous
# 2                f  ...   1.56    72.0  29.59  25       continuous
# 3                t  ...   1.62    54.0  20.58  31       continuous
# 4                f  ...   1.47    51.0  23.60  28       continuous
# ...            ...  ...    ...     ...    ...  ..              ...
# 6152             t  ...   1.56    49.0  20.00  35       continuous
# 6153             f  ...   1.64    59.0  21.51  29       continuous
# 6154             f  ...   1.59    64.0  20.00  39    discontinuous
# 6155             t  ...   1.48    50.0  23.28  41       continuous
# 6156             f  ...   1.65    75.2  24.00  32    discontinuous
#
#       MATERNALEDUCATION SUBSTANCEABUSE  SMOKING ALCOHOL         TYPEOFBIRTH
# 0             secondary              f        f       f  emergencyc-section
# 1             secondary              f        f       f       CESprogrammed
# 2             secondary              f        f       f                 EUT
# 3             secondary              f        f       f                 EUT
# 4             secondary              f        f       f                 EUT
# ...                 ...            ...      ...     ...                 ...
# 6152          secondary              f        f       f                 EUT
# 6153          secondary              f        f       f                 EUT
# 6154          secondary              f        f       t                 EUT
# 6155            primary              f        f       f  emergencyc-section
# 6156        Sinestudios              f        f       f                 EUT
#
# [6140 rows x 33 columns]

# %%
new_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6140 entries, 0 to 6156
# Data columns (total 33 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PREVIOUSCESAREAN            6140 non-null   object
#  1   COMPLICATIONS               6140 non-null   object
#  2   ROBSONGROUP                 6140 non-null   object
#  3   ARTMODE                     6140 non-null   object
#  4   PREVIOUSPRETERMPREGNANCIES  6140 non-null   int64
#  5   AMNIOCENTESIS               6140 non-null   object
#  6   PREINDUCTION                6140 non-null   object
#  7   INDUCTION                   6140 non-null   object
#  8   PARITY                      6140 non-null   int64
#  9   OBSTETRICRISK               6140 non-null   object
#  10  COMORBIDITY                 6140 non-null   object
#  11  NUMBEROFPREVCESAREAN        6140 non-null   float64
#  12  KGINCREASEDPREGNANCY        6140 non-null   int64
#  13  STARTANTENATALCARRE         6140 non-null   object
#  14  ART                         6140 non-null   object
#  15  PREVIOUSTERMPREGNANCIES     6140 non-null   int64
#  16  AMNIOTICLIQUID              6140 non-null   object
#  17  MISCARRIAGES                6140 non-null   int64
#  18  ANESTHESIA                  6140 non-null   object
#  19  EPISIOTOMY                  6140 non-null   object
#  20  OXYTOCIN                    6140 non-null   object
#  21  FetalINTRAPARTUMpH          6140 non-null   object
#  22  GESTAGIONALAGE              6140 non-null   int64
#  23  HEIGHT                      6140 non-null   float64
#  24  WEIGHT                      6140 non-null   float64
#  25  BMI                         6140 non-null   float64
#  26  AGE                         6140 non-null   int64
#  27  CARDIOTOCOGRAPHY            6140 non-null   object
#  28  MATERNALEDUCATION           6140 non-null   object
#  29  SUBSTANCEABUSE              6140 non-null   object
#  30  SMOKING                     6140 non-null   object
#  31  ALCOHOL                     6140 non-null   object
#  32  TYPEOFBIRTH                 6140 non-null   object
# dtypes: float64(4), int64(7), object(22)
# memory usage: 1.6+ MB

# %% [markdown]
# ### Checking NULL values

# %%
new_df1.isnull().sum()
# Out:
# PREVIOUSCESAREAN              0
# COMPLICATIONS                 0
# ROBSONGROUP                   0
# ARTMODE                       0
# PREVIOUSPRETERMPREGNANCIES    0
# AMNIOCENTESIS                 0
# PREINDUCTION                  0
# INDUCTION                     0
# PARITY                        0
# OBSTETRICRISK                 0
# COMORBIDITY                   0
# NUMBEROFPREVCESAREAN          0
# KGINCREASEDPREGNANCY          0
# STARTANTENATALCARRE           0
# ART                           0
# PREVIOUSTERMPREGNANCIES       0
# AMNIOTICLIQUID                0
# MISCARRIAGES                  0
# ANESTHESIA                    0
# EPISIOTOMY                    0
# OXYTOCIN                      0
# FetalINTRAPARTUMpH            0
# GESTAGIONALAGE                0
# HEIGHT                        0
# WEIGHT                        0
# BMI                           0
# AGE                           0
# CARDIOTOCOGRAPHY              0
# MATERNALEDUCATION             0
# SUBSTANCEABUSE                0
# SMOKING                       0
# ALCOHOL                       0
# TYPEOFBIRTH                   0
# dtype: int64

# %%
new_df1.TYPEOFBIRTH.unique()
# Out:
# array(['emergencyc-section', 'CESprogrammed', 'EUT', 'vacum', 'FORC',
#        'ESP', 'NALGASVAGINAL'], dtype=object)

# %%
a = new_df1['TYPEOFBIRTH'].values.tolist()
s = set(a)
for x in s:
  print(x,":",a.count(x))
# Out:
# EUT : 4222
# emergencyc-section : 689
# CESprogrammed : 325
# FORC : 87
# ESP : 44
# NALGASVAGINAL : 8
# vacum : 765

# %%
new_df1
# Out:
#      PREVIOUSCESAREAN COMPLICATIONS ROBSONGROUP ARTMODE  \
# 0                   f             f     group2a     FIV
# 1                   f             f      group6     FIV
# 2                   f             f      group1     FIV
# 3                   t             f      group5     FIV
# 4                   f             f      group1     FIV
# ...               ...           ...         ...     ...
# 6152                f             f      group8     FIV
# 6153                f             f      group3     FIV
# 6154                f             f      group1     IAD
# 6155                f             f     group2a     FIV
# 6156                f             f      group3     FIV
#
#       PREVIOUSPRETERMPREGNANCIES AMNIOCENTESIS PREINDUCTION INDUCTION  PARITY  \
# 0                              0             f            t         t       0
# 1                              0             f            f         f      10
# 2                              0             f            f         f      10
# 3                              0             f            f         f    1001
# 4                              0             f            f         f      10
# ...                          ...           ...          ...       ...     ...
# 6152                           0             t            f         f       0
# 6153                           0             f            f         f    1001
# 6154                           0             f            f         f      20
# 6155                           0             f            f         t    1020
# 6156                           0             f            f         f    2002
#
#      OBSTETRICRISK  ... HEIGHT  WEIGHT    BMI AGE CARDIOTOCOGRAPHY  \
# 0                t  ...   1.58    70.0  28.04  30       continuous
# 1                f  ...   1.61    79.0  30.48  38       continuous
# 2                f  ...   1.56    72.0  29.59  25       continuous
# 3                t  ...   1.62    54.0  20.58  31       continuous
# 4                f  ...   1.47    51.0  23.60  28       continuous
# ...            ...  ...    ...     ...    ...  ..              ...
# 6152             t  ...   1.56    49.0  20.00  35       continuous
# 6153             f  ...   1.64    59.0  21.51  29       continuous
# 6154             f  ...   1.59    64.0  20.00  39    discontinuous
# 6155             t  ...   1.48    50.0  23.28  41       continuous
# 6156             f  ...   1.65    75.2  24.00  32    discontinuous
#
#       MATERNALEDUCATION SUBSTANCEABUSE  SMOKING ALCOHOL         TYPEOFBIRTH
# 0             secondary              f        f       f  emergencyc-section
# 1             secondary              f        f       f       CESprogrammed
# 2             secondary              f        f       f                 EUT
# 3             secondary              f        f       f                 EUT
# 4             secondary              f        f       f                 EUT
# ...                 ...            ...      ...     ...                 ...
# 6152          secondary              f        f       f                 EUT
# 6153          secondary              f        f       f                 EUT
# 6154          secondary              f        f       t                 EUT
# 6155            primary              f        f       f  emergencyc-section
# 6156        Sinestudios              f        f       f                 EUT
#
# [6140 rows x 33 columns]

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

#new_df1.Publisher = new_df1.Publisher.astype(str)

for column in new_df1.columns:
    temp_new = le.fit_transform(new_df1[column].astype('category'))
    new_df1.drop(labels=[column], axis="columns", inplace=True)
    new_df1[column] = temp_new

X = new_df1.loc[:,'PREVIOUSCESAREAN':'ALCOHOL']
Y = new_df1.loc[:,'TYPEOFBIRTH':]

# %%
from imblearn.over_sampling import ADASYN 
sm = ADASYN(sampling_strategy='auto', random_state=None, n_neighbors=5, n_jobs=1)
X_adassin_1, Y_adassin_1 = sm.fit_resample(X, Y)
print(X_adassin_1.shape)
print(Y_adassin_1.shape)
# Out:
# (29470, 32)
# (29470, 1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X_adassin_1,Y_adassin_1,test_size=0.2,random_state=None)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23576 entries, 22950 to 21940
# Data columns (total 32 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PREVIOUSCESAREAN            23576 non-null  int64
#  1   COMPLICATIONS               23576 non-null  int64
#  2   ROBSONGROUP                 23576 non-null  int64
#  3   ARTMODE                     23576 non-null  int64
#  4   PREVIOUSPRETERMPREGNANCIES  23576 non-null  int64
#  5   AMNIOCENTESIS               23576 non-null  int64
#  6   PREINDUCTION                23576 non-null  int64
#  7   INDUCTION                   23576 non-null  int64
#  8   PARITY                      23576 non-null  int64
#  9   OBSTETRICRISK               23576 non-null  int64
#  10  COMORBIDITY                 23576 non-null  int64
#  11  NUMBEROFPREVCESAREAN        23576 non-null  int64
#  12  KGINCREASEDPREGNANCY        23576 non-null  int64
#  13  STARTANTENATALCARRE         23576 non-null  int64
#  14  ART                         23576 non-null  int64
#  15  PREVIOUSTERMPREGNANCIES     23576 non-null  int64
#  16  AMNIOTICLIQUID              23576 non-null  int64
#  17  MISCARRIAGES                23576 non-null  int64
#  18  ANESTHESIA                  23576 non-null  int64
#  19  EPISIOTOMY                  23576 non-null  int64
#  20  OXYTOCIN                    23576 non-null  int64
#  21  FetalINTRAPARTUMpH          23576 non-null  int64
#  22  GESTAGIONALAGE              23576 non-null  int64
#  23  HEIGHT                      23576 non-null  int64
#  24  WEIGHT                      23576 non-null  int64
#  25  BMI                         23576 non-null  int64
#  26  AGE                         23576 non-null  int64
#  27  CARDIOTOCOGRAPHY            23576 non-null  int64
#  28  MATERNALEDUCATION           23576 non-null  int64
#  29  SUBSTANCEABUSE              23576 non-null  int64
#  30  SMOKING                     23576 non-null  int64
#  31  ALCOHOL                     23576 non-null  int64
# dtypes: int64(32)
# memory usage: 5.9 MB

# %%
Y_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23576 entries, 22950 to 21940
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TYPEOFBIRTH  23576 non-null  int64
# dtypes: int64(1)
# memory usage: 368.4 KB

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5894 entries, 1794 to 18259
# Data columns (total 32 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PREVIOUSCESAREAN            5894 non-null   int64
#  1   COMPLICATIONS               5894 non-null   int64
#  2   ROBSONGROUP                 5894 non-null   int64
#  3   ARTMODE                     5894 non-null   int64
#  4   PREVIOUSPRETERMPREGNANCIES  5894 non-null   int64
#  5   AMNIOCENTESIS               5894 non-null   int64
#  6   PREINDUCTION                5894 non-null   int64
#  7   INDUCTION                   5894 non-null   int64
#  8   PARITY                      5894 non-null   int64
#  9   OBSTETRICRISK               5894 non-null   int64
#  10  COMORBIDITY                 5894 non-null   int64
#  11  NUMBEROFPREVCESAREAN        5894 non-null   int64
#  12  KGINCREASEDPREGNANCY        5894 non-null   int64
#  13  STARTANTENATALCARRE         5894 non-null   int64
#  14  ART                         5894 non-null   int64
#  15  PREVIOUSTERMPREGNANCIES     5894 non-null   int64
#  16  AMNIOTICLIQUID              5894 non-null   int64
#  17  MISCARRIAGES                5894 non-null   int64
#  18  ANESTHESIA                  5894 non-null   int64
#  19  EPISIOTOMY                  5894 non-null   int64
#  20  OXYTOCIN                    5894 non-null   int64
#  21  FetalINTRAPARTUMpH          5894 non-null   int64
#  22  GESTAGIONALAGE              5894 non-null   int64
#  23  HEIGHT                      5894 non-null   int64
#  24  WEIGHT                      5894 non-null   int64
#  25  BMI                         5894 non-null   int64
#  26  AGE                         5894 non-null   int64
#  27  CARDIOTOCOGRAPHY            5894 non-null   int64
#  28  MATERNALEDUCATION           5894 non-null   int64
#  29  SUBSTANCEABUSE              5894 non-null   int64
#  30  SMOKING                     5894 non-null   int64
#  31  ALCOHOL                     5894 non-null   int64
# dtypes: int64(32)
# memory usage: 1.5 MB

# %%
Y_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5894 entries, 1794 to 18259
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TYPEOFBIRTH  5894 non-null   int64
# dtypes: int64(1)
# memory usage: 92.1 KB

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
model = DecisionTreeClassifier(criterion = 'entropy')
model.fit(X_train,Y_train)
y_pred = model.predict(X_test)
print(accuracy_score(Y_test,y_pred))
print(precision_score(Y_test,y_pred,pos_label='positive',average='weighted'))
print(recall_score(Y_test,y_pred,pos_label='positive',average='micro'))

all_dt_f1 = f1_score(Y_test, y_pred,average='micro')

print(all_dt_f1)
# Out:
# 0.8727519511367492
# 0.8704394934668102
# 0.8727519511367492
# 0.8727519511367492
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,

# %%
from sklearn.ensemble import RandomForestClassifier
RFC = RandomForestClassifier()
RFC.fit(X_train, Y_train.values.ravel())
y_pred = RFC.predict(X_test)
print(accuracy_score(Y_test,y_pred))
print(precision_score(Y_test,y_pred,pos_label='positive',average='weighted'))
print(recall_score(Y_test,y_pred,pos_label='positive',average='micro'))

all_rfc_f1 = f1_score(Y_test, y_pred,average='micro')

print(all_rfc_f1)
# Out:
# 0.9328130302002036
# 0.931883860252814
# 0.9328130302002036
# 0.9328130302002036
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,

# %%
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score
svc = SVC(gamma = 0.001, C = 1000)
y_pred = svc.fit(X_train, Y_train.values.ravel()).predict(X_test)
print(accuracy_score(Y_test,y_pred))
print(precision_score(Y_test,y_pred,pos_label='positive',average='weighted'))
print(recall_score(Y_test,y_pred,pos_label='positive',average='micro'))

all_svc_f1 = f1_score(Y_test, y_pred,average='micro')

print(all_svc_f1)
# Out:
# 0.9294197488971836
# 0.9280527135239902
# 0.9294197488971836
# 0.9294197488971836
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,

# %%
from sklearn.neighbors import KNeighborsClassifier
K = []
training = []
test = []
scores = {}
  
for k in range(2, 21):
    clf = KNeighborsClassifier(n_neighbors = k)
    clf.fit(X_train, Y_train.values.ravel())
  
    training_score = clf.score(X_train, Y_train)
    test_score = clf.score(X_test, Y_test)
    K.append(k)
  
    training.append(training_score)
    test.append(test_score)
    scores[k] = [training_score, test_score]
for keys, values in scores.items():
    print(keys, ':', values)
# Out:
# 2 : [0.952281981676281, 0.843400067865626]
# 3 : [0.9158042076688158, 0.836274177129284]
# 4 : [0.8934509670851714, 0.8137088564642009]
# 5 : [0.870249406175772, 0.8053953172718018]
# 6 : [0.8500593824228029, 0.7884289107567017]
# 7 : [0.8360620970478453, 0.7777400746521886]
# 8 : [0.8197743467933492, 0.7636579572446556]
# 9 : [0.8071767899558874, 0.7524601289446895]
# 10 : [0.7939429928741093, 0.7404139803189684]
# 11 : [0.7808788598574822, 0.7315914489311164]
# 12 : [0.7692568713946386, 0.7236172378690193]
# 13 : [0.7600950118764845, 0.7136070580251103]
# 14 : [0.7489820156090939, 0.7066508313539193]
# 15 : [0.7407108924329827, 0.6996946046827281]
# 16 : [0.7314642008822532, 0.6935866983372921]
# 17 : [0.7239989820156091, 0.6862911435357991]
# 18 : [0.7178486596538853, 0.6825585341024771]
# 19 : [0.7079657278588395, 0.675262979300984]
# 20 : [0.7016457414319647, 0.664913471326773]

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=2,weights='distance',p=1)
model.fit(X_train,Y_train.values.ravel())
y_pred = model.predict(X_test)
print(accuracy_score(Y_test,y_pred))
print(precision_score(Y_test,y_pred,pos_label='positive',average='weighted'))
print(recall_score(Y_test,y_pred,pos_label='positive',average='micro'))

all_knn_f1 = f1_score(Y_test, y_pred,average='micro')

print(all_knn_f1)
# Out:
# 0.9100780454699695
# 0.9102636824424933
# 0.9100780454699695
# 0.9100780454699695
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,

# %%
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import StackingClassifier
estimators = [('rf', RandomForestClassifier()),('svr', make_pipeline(StandardScaler(),LinearSVC())),('dt',DecisionTreeClassifier(criterion = 'entropy')),('knn',KNeighborsClassifier(n_neighbors=2,weights='distance',p=1))]
clf = StackingClassifier(estimators=estimators, final_estimator=LogisticRegression())
clf.fit(X_train, Y_train.values.ravel())
y_pred = clf.predict(X_test)
print(accuracy_score(Y_test,y_pred))
print(precision_score(Y_test,y_pred,pos_label='positive',average='weighted'))
print(recall_score(Y_test,y_pred,pos_label='positive',average='micro'))

all_sc_f1 = f1_score(Y_test, y_pred,average='micro')

print(all_sc_f1)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# 0.9658975229046488
# 0.9657990890412904
# 0.9658975229046488
# 0.9658975229046488
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,

# %%
h_df = c_df[['PREVIOUSCESAREAN','COMPLICATIONS','ROBSONGROUP','ARTMODE','PREVIOUSPRETERMPREGNANCIES','AMNIOCENTESIS','PREINDUCTION','INDUCTION',
        'EPISIOTOMY','OXYTOCIN','FetalINTRAPARTUMpH','TYPEOFBIRTH']]
  
h_df
# Out:
#      PREVIOUSCESAREAN COMPLICATIONS ROBSONGROUP ARTMODE  \
# 0                   f             f     group2a     NaN
# 1                   f             f      group6     NaN
# 2                   f             f      group1     NaN
# 3                   t             f      group5     NaN
# 4                   f             f      group1     FIV
# ...               ...           ...         ...     ...
# 6152                f             f      group8     NaN
# 6153                f             f      group3     NaN
# 6154                f             f      group1     IAD
# 6155                f             f     group2a     FIV
# 6156                f             f      group3     NaN
#
#       PREVIOUSPRETERMPREGNANCIES AMNIOCENTESIS PREINDUCTION INDUCTION  \
# 0                              0             f            t         t
# 1                              0             f            f         f
# 2                              0             f            f         f
# 3                              0             f            f         f
# 4                              0             f            f         f
# ...                          ...           ...          ...       ...
# 6152                           0             t            f         f
# 6153                           0             f            f         f
# 6154                           0             f            f         f
# 6155                           0             f            f         t
# 6156                           0             f            f         f
#
#      EPISIOTOMY OXYTOCIN FetalINTRAPARTUMpH         TYPEOFBIRTH
# 0           NaN        t                  f  emergencyc-section
# 1           NaN        f                  f       CESprogrammed
# 2             f        t                  f                 EUT
# 3             f        f                  f                 EUT
# 4             f        t                  f                 EUT
# ...         ...      ...                ...                 ...
# 6152          t        f                  f                 EUT
# 6153          f        f                  f                 EUT
# 6154          f        f                  f                 EUT
# 6155          f        t                  t  emergencyc-section
# 6156          f        f                  f                 EUT
#
# [6157 rows x 12 columns]

# %% [markdown]
# ### Checking duplicates

# %%
h_df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6152    False
# 6153     True
# 6154    False
# 6155    False
# 6156     True
# Length: 6157, dtype: bool

# %%
h_df.duplicated().sum()
# Out:
# 5261

# %% [markdown]
# ### Drop duplicate records

# %%
h_df = h_df.drop_duplicates()
h_df
# Out:
#      PREVIOUSCESAREAN COMPLICATIONS ROBSONGROUP ARTMODE  \
# 0                   f             f     group2a     NaN
# 1                   f             f      group6     NaN
# 2                   f             f      group1     NaN
# 3                   t             f      group5     NaN
# 4                   f             f      group1     FIV
# ...               ...           ...         ...     ...
# 6143                f             f     group2b  Ovodón
# 6149                f             f     group2a     NaN
# 6152                f             f      group8     NaN
# 6154                f             f      group1     IAD
# 6155                f             f     group2a     FIV
#
#       PREVIOUSPRETERMPREGNANCIES AMNIOCENTESIS PREINDUCTION INDUCTION  \
# 0                              0             f            t         t
# 1                              0             f            f         f
# 2                              0             f            f         f
# 3                              0             f            f         f
# 4                              0             f            f         f
# ...                          ...           ...          ...       ...
# 6143                           0             f            f         f
# 6149                           0             f            f         t
# 6152                           0             t            f         f
# 6154                           0             f            f         f
# 6155                           0             f            f         t
#
#      EPISIOTOMY OXYTOCIN FetalINTRAPARTUMpH         TYPEOFBIRTH
# 0           NaN        t                  f  emergencyc-section
# 1           NaN        f                  f       CESprogrammed
# 2             f        t                  f                 EUT
# 3             f        f                  f                 EUT
# 4             f        t                  f                 EUT
# ...         ...      ...                ...                 ...
# 6143          f        f                  f       CESprogrammed
# 6149          f        f                  f                FORC
# 6152          t        f                  f                 EUT
# 6154          f        f                  f                 EUT
# 6155          f        t                  t  emergencyc-section
#
# [896 rows x 12 columns]

# %%
h_df = h_df.replace(r'^\s*$', np.nan, regex=True)

# %% [markdown]
# ### Handling missing values of categorical attributes by mode

# %%
s = (h_df.dtypes == 'object')
#print(s)
#print(s[s])
object_cols = list(s[s].index)
print("Categorical variables:")
print(object_cols)
print(len(object_cols))
# Out:
# Categorical variables:
# ['PREVIOUSCESAREAN', 'COMPLICATIONS', 'ROBSONGROUP', 'ARTMODE', 'AMNIOCENTESIS', 'PREINDUCTION', 'INDUCTION', 'EPISIOTOMY', 'OXYTOCIN', 'FetalINTRAPARTUMpH', 'TYPEOFBIRTH']
# 11

# %%
for i in object_cols:
  x = h_df[i].mode()[0]
  h_df[i].fillna(x,inplace = True)

  
h_df
# Out:
#      PREVIOUSCESAREAN COMPLICATIONS ROBSONGROUP ARTMODE  \
# 0                   f             f     group2a     FIV
# 1                   f             f      group6     FIV
# 2                   f             f      group1     FIV
# 3                   t             f      group5     FIV
# 4                   f             f      group1     FIV
# ...               ...           ...         ...     ...
# 6143                f             f     group2b  Ovodón
# 6149                f             f     group2a     FIV
# 6152                f             f      group8     FIV
# 6154                f             f      group1     IAD
# 6155                f             f     group2a     FIV
#
#       PREVIOUSPRETERMPREGNANCIES AMNIOCENTESIS PREINDUCTION INDUCTION  \
# 0                              0             f            t         t
# 1                              0             f            f         f
# 2                              0             f            f         f
# 3                              0             f            f         f
# 4                              0             f            f         f
# ...                          ...           ...          ...       ...
# 6143                           0             f            f         f
# 6149                           0             f            f         t
# 6152                           0             t            f         f
# 6154                           0             f            f         f
# 6155                           0             f            f         t
#
#      EPISIOTOMY OXYTOCIN FetalINTRAPARTUMpH         TYPEOFBIRTH
# 0             f        t                  f  emergencyc-section
# 1             f        f                  f       CESprogrammed
# 2             f        t                  f                 EUT
# 3             f        f                  f                 EUT
# 4             f        t                  f                 EUT
# ...         ...      ...                ...                 ...
# 6143          f        f                  f       CESprogrammed
# 6149          f        f                  f                FORC
# 6152          t        f                  f                 EUT
# 6154          f        f                  f                 EUT
# 6155          f        t                  t  emergencyc-section
#
# [896 rows x 12 columns]

# %% [markdown]
# ### Handling missing values of Numerical attributes using mean

# %%
s = (h_df.dtypes != 'object')
number_cols = list(s[s].index)
print("Numerical variables:")
print(number_cols)
print(len(number_cols))
# Out:
# Numerical variables:
# ['PREVIOUSPRETERMPREGNANCIES']
# 1

# %%
for i in number_cols:
  x = h_df[i].mean()
  h_df[i].fillna(x,inplace = True)

  
h_df
# Out:
#      PREVIOUSCESAREAN COMPLICATIONS ROBSONGROUP ARTMODE  \
# 0                   f             f     group2a     FIV
# 1                   f             f      group6     FIV
# 2                   f             f      group1     FIV
# 3                   t             f      group5     FIV
# 4                   f             f      group1     FIV
# ...               ...           ...         ...     ...
# 6143                f             f     group2b  Ovodón
# 6149                f             f     group2a     FIV
# 6152                f             f      group8     FIV
# 6154                f             f      group1     IAD
# 6155                f             f     group2a     FIV
#
#       PREVIOUSPRETERMPREGNANCIES AMNIOCENTESIS PREINDUCTION INDUCTION  \
# 0                              0             f            t         t
# 1                              0             f            f         f
# 2                              0             f            f         f
# 3                              0             f            f         f
# 4                              0             f            f         f
# ...                          ...           ...          ...       ...
# 6143                           0             f            f         f
# 6149                           0             f            f         t
# 6152                           0             t            f         f
# 6154                           0             f            f         f
# 6155                           0             f            f         t
#
#      EPISIOTOMY OXYTOCIN FetalINTRAPARTUMpH         TYPEOFBIRTH
# 0             f        t                  f  emergencyc-section
# 1             f        f                  f       CESprogrammed
# 2             f        t                  f                 EUT
# 3             f        f                  f                 EUT
# 4             f        t                  f                 EUT
# ...         ...      ...                ...                 ...
# 6143          f        f                  f       CESprogrammed
# 6149          f        f                  f                FORC
# 6152          t        f                  f                 EUT
# 6154          f        f                  f                 EUT
# 6155          f        t                  t  emergencyc-section
#
# [896 rows x 12 columns]

# %%
h_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 896 entries, 0 to 6155
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PREVIOUSCESAREAN            896 non-null    object
#  1   COMPLICATIONS               896 non-null    object
#  2   ROBSONGROUP                 896 non-null    object
#  3   ARTMODE                     896 non-null    object
#  4   PREVIOUSPRETERMPREGNANCIES  896 non-null    int64
#  5   AMNIOCENTESIS               896 non-null    object
#  6   PREINDUCTION                896 non-null    object
#  7   INDUCTION                   896 non-null    object
#  8   EPISIOTOMY                  896 non-null    object
#  9   OXYTOCIN                    896 non-null    object
#  10  FetalINTRAPARTUMpH          896 non-null    object
#  11  TYPEOFBIRTH                 896 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 91.0+ KB

# %% [markdown]
# ### Checking NULL values

# %%
h_df.isnull().sum()
# Out:
# PREVIOUSCESAREAN              0
# COMPLICATIONS                 0
# ROBSONGROUP                   0
# ARTMODE                       0
# PREVIOUSPRETERMPREGNANCIES    0
# AMNIOCENTESIS                 0
# PREINDUCTION                  0
# INDUCTION                     0
# EPISIOTOMY                    0
# OXYTOCIN                      0
# FetalINTRAPARTUMpH            0
# TYPEOFBIRTH                   0
# dtype: int64

# %%
h_df.TYPEOFBIRTH.unique()
# Out:
# array(['emergencyc-section', 'CESprogrammed', 'EUT', 'vacum', 'FORC',
#        'ESP', 'NALGASVAGINAL'], dtype=object)

# %%
a = h_df['TYPEOFBIRTH'].values.tolist()
s = set(a)
for x in s:
  print(x,":",a.count(x))
# Out:
# EUT : 357
# emergencyc-section : 200
# CESprogrammed : 67
# FORC : 38
# ESP : 29
# NALGASVAGINAL : 6
# vacum : 199

# %%
h_df
# Out:
#      PREVIOUSCESAREAN COMPLICATIONS ROBSONGROUP ARTMODE  \
# 0                   f             f     group2a     FIV
# 1                   f             f      group6     FIV
# 2                   f             f      group1     FIV
# 3                   t             f      group5     FIV
# 4                   f             f      group1     FIV
# ...               ...           ...         ...     ...
# 6143                f             f     group2b  Ovodón
# 6149                f             f     group2a     FIV
# 6152                f             f      group8     FIV
# 6154                f             f      group1     IAD
# 6155                f             f     group2a     FIV
#
#       PREVIOUSPRETERMPREGNANCIES AMNIOCENTESIS PREINDUCTION INDUCTION  \
# 0                              0             f            t         t
# 1                              0             f            f         f
# 2                              0             f            f         f
# 3                              0             f            f         f
# 4                              0             f            f         f
# ...                          ...           ...          ...       ...
# 6143                           0             f            f         f
# 6149                           0             f            f         t
# 6152                           0             t            f         f
# 6154                           0             f            f         f
# 6155                           0             f            f         t
#
#      EPISIOTOMY OXYTOCIN FetalINTRAPARTUMpH         TYPEOFBIRTH
# 0             f        t                  f  emergencyc-section
# 1             f        f                  f       CESprogrammed
# 2             f        t                  f                 EUT
# 3             f        f                  f                 EUT
# 4             f        t                  f                 EUT
# ...         ...      ...                ...                 ...
# 6143          f        f                  f       CESprogrammed
# 6149          f        f                  f                FORC
# 6152          t        f                  f                 EUT
# 6154          f        f                  f                 EUT
# 6155          f        t                  t  emergencyc-section
#
# [896 rows x 12 columns]

# %%
le = preprocessing.LabelEncoder()

#new_df1.Publisher = new_df1.Publisher.astype(str)

for column in h_df.columns:
    temp_new = le.fit_transform(h_df[column].astype('category'))
    h_df.drop(labels=[column], axis="columns", inplace=True)
    h_df[column] = temp_new

X_h = h_df.loc[:,'PREVIOUSCESAREAN':'FetalINTRAPARTUMpH']
Y_h = h_df.loc[:,'TYPEOFBIRTH':]

# %%
sm = ADASYN(sampling_strategy='minority', random_state=None, n_neighbors=5, n_jobs=1)
X_adassin_h, Y_adassin_h = sm.fit_resample(X_h, Y_h)
print(X_adassin_h.shape)
print(Y_adassin_h.shape)
# Out:
# (1248, 11)
# (1248, 1)

# %%
X_train_h, X_test_h, Y_train_h, Y_test_h = train_test_split(X_adassin_h,Y_adassin_h,test_size=0.20,random_state=None)

# %%
X_train_h.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 998 entries, 1009 to 849
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PREVIOUSCESAREAN            998 non-null    int64
#  1   COMPLICATIONS               998 non-null    int64
#  2   ROBSONGROUP                 998 non-null    int64
#  3   ARTMODE                     998 non-null    int64
#  4   PREVIOUSPRETERMPREGNANCIES  998 non-null    int64
#  5   AMNIOCENTESIS               998 non-null    int64
#  6   PREINDUCTION                998 non-null    int64
#  7   INDUCTION                   998 non-null    int64
#  8   EPISIOTOMY                  998 non-null    int64
#  9   OXYTOCIN                    998 non-null    int64
#  10  FetalINTRAPARTUMpH          998 non-null    int64
# dtypes: int64(11)
# memory usage: 93.6 KB

# %%
Y_train_h.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 998 entries, 1009 to 849
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TYPEOFBIRTH  998 non-null    int64
# dtypes: int64(1)
# memory usage: 15.6 KB

# %%
X_test_h.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 250 entries, 299 to 286
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PREVIOUSCESAREAN            250 non-null    int64
#  1   COMPLICATIONS               250 non-null    int64
#  2   ROBSONGROUP                 250 non-null    int64
#  3   ARTMODE                     250 non-null    int64
#  4   PREVIOUSPRETERMPREGNANCIES  250 non-null    int64
#  5   AMNIOCENTESIS               250 non-null    int64
#  6   PREINDUCTION                250 non-null    int64
#  7   INDUCTION                   250 non-null    int64
#  8   EPISIOTOMY                  250 non-null    int64
#  9   OXYTOCIN                    250 non-null    int64
#  10  FetalINTRAPARTUMpH          250 non-null    int64
# dtypes: int64(11)
# memory usage: 23.4 KB

# %%
Y_test_h.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 250 entries, 299 to 286
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TYPEOFBIRTH  250 non-null    int64
# dtypes: int64(1)
# memory usage: 3.9 KB

# %%
model = DecisionTreeClassifier(criterion = 'entropy')
model.fit(X_train_h,Y_train_h)
y_pred_h = model.predict(X_test_h)
print(accuracy_score(Y_test_h,y_pred_h))
print(precision_score(Y_test_h,y_pred_h,pos_label='positive',average='weighted'))
print(recall_score(Y_test_h,y_pred_h,pos_label='positive',average='micro'))

h_dt_f1 = f1_score(Y_test_h, y_pred_h,average='micro')

print(h_dt_f1)
# Out:
# 0.456
# 0.44084206154987027
# 0.456
# 0.456
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,

# %%
RFC = RandomForestClassifier()
RFC.fit(X_train_h, Y_train_h.values.ravel())
y_pred_h = RFC.predict(X_test_h)
print(accuracy_score(Y_test_h,y_pred_h))
print(precision_score(Y_test_h,y_pred_h,pos_label='positive',average='weighted'))
print(recall_score(Y_test_h,y_pred_h,pos_label='positive',average='micro'))

h_rfc_f1 = f1_score(Y_test_h, y_pred_h,average='micro')

print(h_rfc_f1)
# Out:
# 0.464
# 0.46564716001104756
# 0.464
# 0.464
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,

# %%
svc = SVC(gamma = 0.001, C = 1000)
y_pred_h = svc.fit(X_train_h, Y_train_h.values.ravel()).predict(X_test_h)
print(accuracy_score(Y_test_h,y_pred_h))
print(precision_score(Y_test_h,y_pred_h,pos_label='positive',average='weighted'))
print(recall_score(Y_test_h,y_pred_h,pos_label='positive',average='micro'))

h_svc_f1 = f1_score(Y_test_h, y_pred_h,average='micro')

print(h_svc_f1)
# Out:
# 0.592
# 0.5622680794056752
# 0.592
# 0.592
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,

# %%
K = []
training = []
test = []
scores = {}
  
for k in range(2, 21):
    clf = KNeighborsClassifier(n_neighbors = k)
    clf.fit(X_train_h, Y_train_h.values.ravel())
  
    training_score = clf.score(X_train_h, Y_train_h)
    test_score = clf.score(X_test_h, Y_test_h)
    K.append(k)
  
    training.append(training_score)
    test.append(test_score)
    scores[k] = [training_score, test_score]
for keys, values in scores.items():
    print(keys, ':', values)
# Out:
# 2 : [0.6513026052104208, 0.484]
# 3 : [0.6533066132264529, 0.508]
# 4 : [0.6533066132264529, 0.488]
# 5 : [0.6362725450901804, 0.528]
# 6 : [0.6352705410821643, 0.516]
# 7 : [0.6212424849699398, 0.532]
# 8 : [0.6162324649298597, 0.564]
# 9 : [0.6202404809619239, 0.528]
# 10 : [0.6202404809619239, 0.552]
# 11 : [0.6142284569138277, 0.552]
# 12 : [0.6112224448897795, 0.572]
# 13 : [0.6122244488977956, 0.564]
# 14 : [0.6082164328657315, 0.568]
# 15 : [0.6082164328657315, 0.548]
# 16 : [0.6052104208416834, 0.552]
# 17 : [0.5971943887775552, 0.56]
# 18 : [0.5981963927855711, 0.556]
# 19 : [0.593186372745491, 0.548]
# 20 : [0.6002004008016032, 0.54]

# %%
model = KNeighborsClassifier(n_neighbors=2,weights='distance',p=1)
model.fit(X_train_h,Y_train_h.values.ravel())
y_pred_h = model.predict(X_test_h)
print(accuracy_score(Y_test_h,y_pred_h))
print(precision_score(Y_test_h,y_pred_h,pos_label='positive',average='weighted'))
print(recall_score(Y_test_h,y_pred_h,pos_label='positive',average='micro'))

h_knn_f1 = f1_score(Y_test_h, y_pred_h,average='micro')

print(h_knn_f1)
# Out:
# 0.46
# 0.42900750862663906
# 0.46
# 0.46
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,

# %%
estimators = [('rf', RandomForestClassifier()),('svr', make_pipeline(StandardScaler(),LinearSVC())),('dt',DecisionTreeClassifier(criterion = 'entropy')),('knn',KNeighborsClassifier(n_neighbors=2,weights='distance',p=1))]
clf = StackingClassifier(estimators=estimators, final_estimator=LogisticRegression())
clf.fit(X_train_h, Y_train_h.values.ravel())
y_pred_h = clf.predict(X_test_h)
print(accuracy_score(Y_test_h,y_pred_h))
print(precision_score(Y_test_h,y_pred_h,pos_label='positive',average='weighted'))
print(recall_score(Y_test_h,y_pred_h,pos_label='positive',average='micro'))

h_sc_f1 = f1_score(Y_test_h, y_pred_h,average='micro')
print(h_sc_f1)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# 0.62
# 0.5909579496149955
# 0.62
# 0.62
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,

# %%
m_df = c_df[['PARITY','OBSTETRICRISK','COMORBIDITY','NUMBEROFPREVCESAREAN','KGINCREASEDPREGNANCY','STARTANTENATALCARRE',
        'ART','PREVIOUSTERMPREGNANCIES','AMNIOTICLIQUID','MISCARRIAGES','ANESTHESIA','TYPEOFBIRTH']]

# %% [markdown]
# ### Checking duplicates

# %%
m_df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6152    False
# 6153     True
# 6154    False
# 6155    False
# 6156     True
# Length: 6157, dtype: bool

# %%
m_df.duplicated().sum()
# Out:
# 2259

# %% [markdown]
# ### Drop duplicate records

# %%
m_df = m_df.drop_duplicates()
m_df
# Out:
#       PARITY OBSTETRICRISK COMORBIDITY  NUMBEROFPREVCESAREAN  \
# 0          0             t           f                   NaN
# 1         10             f           f                   NaN
# 2         10             f           f                   NaN
# 3       1001             t           f                   1.0
# 4         10             f           f                   NaN
# ...      ...           ...         ...                   ...
# 6149       0             t           f                   0.0
# 6151       0             f           f                   0.0
# 6152       0             t           t                   0.0
# 6154      20             f           f                   0.0
# 6155    1020             t           f                   0.0
#
#       KGINCREASEDPREGNANCY STARTANTENATALCARRE ART  PREVIOUSTERMPREGNANCIES  \
# 0                       14         1ºtrimester   f                        0
# 1                        5         1ºtrimester   f                        0
# 2                       12         1ºtrimester   f                        0
# 3                       12         1ºtrimester   f                        1
# 4                       11         1ºtrimester   t                        0
# ...                    ...                 ...  ..                      ...
# 6149                     0         1ºtrimester   f                        0
# 6151                     0         2ºtrimester   f                        0
# 6152                    13         1ºtrimester   f                        0
# 6154                     0         1ºtrimester   t                        0
# 6155                     3         1ºtrimester   t                        1
#
#      AMNIOTICLIQUID  MISCARRIAGES ANESTHESIA         TYPEOFBIRTH
# 0          stained+             0          t  emergencyc-section
# 1             clear             1          t       CESprogrammed
# 2             clear             1          t                 EUT
# 3          stained+             0          t                 EUT
# 4             clear             1          t                 EUT
# ...             ...           ...        ...                 ...
# 6149    Hemorrágico             0          t                FORC
# 6151       stained+             0          t  emergencyc-section
# 6152          clear             0          t                 EUT
# 6154          clear             2          t                 EUT
# 6155          clear             2          t  emergencyc-section
#
# [3898 rows x 12 columns]

# %%
m_df = m_df.replace(r'^\s*$', np.nan, regex=True)

# %% [markdown]
# ### Handling missing values of categorical attributes by mode

# %%
s = (m_df.dtypes == 'object')
#print(s)
#print(s[s])
object_cols = list(s[s].index)
print("Categorical variables:")
print(object_cols)
print(len(object_cols))
# Out:
# Categorical variables:
# ['OBSTETRICRISK', 'COMORBIDITY', 'STARTANTENATALCARRE', 'ART', 'AMNIOTICLIQUID', 'ANESTHESIA', 'TYPEOFBIRTH']
# 7

# %%
for i in object_cols:
  x = m_df[i].mode()[0]
  m_df[i].fillna(x,inplace = True)
m_df
# Out:
#       PARITY OBSTETRICRISK COMORBIDITY  NUMBEROFPREVCESAREAN  \
# 0          0             t           f                   NaN
# 1         10             f           f                   NaN
# 2         10             f           f                   NaN
# 3       1001             t           f                   1.0
# 4         10             f           f                   NaN
# ...      ...           ...         ...                   ...
# 6149       0             t           f                   0.0
# 6151       0             f           f                   0.0
# 6152       0             t           t                   0.0
# 6154      20             f           f                   0.0
# 6155    1020             t           f                   0.0
#
#       KGINCREASEDPREGNANCY STARTANTENATALCARRE ART  PREVIOUSTERMPREGNANCIES  \
# 0                       14         1ºtrimester   f                        0
# 1                        5         1ºtrimester   f                        0
# 2                       12         1ºtrimester   f                        0
# 3                       12         1ºtrimester   f                        1
# 4                       11         1ºtrimester   t                        0
# ...                    ...                 ...  ..                      ...
# 6149                     0         1ºtrimester   f                        0
# 6151                     0         2ºtrimester   f                        0
# 6152                    13         1ºtrimester   f                        0
# 6154                     0         1ºtrimester   t                        0
# 6155                     3         1ºtrimester   t                        1
#
#      AMNIOTICLIQUID  MISCARRIAGES ANESTHESIA         TYPEOFBIRTH
# 0          stained+             0          t  emergencyc-section
# 1             clear             1          t       CESprogrammed
# 2             clear             1          t                 EUT
# 3          stained+             0          t                 EUT
# 4             clear             1          t                 EUT
# ...             ...           ...        ...                 ...
# 6149    Hemorrágico             0          t                FORC
# 6151       stained+             0          t  emergencyc-section
# 6152          clear             0          t                 EUT
# 6154          clear             2          t                 EUT
# 6155          clear             2          t  emergencyc-section
#
# [3898 rows x 12 columns]

# %% [markdown]
# ### Handling missing values of Numerical attributes using mean

# %%
s = (m_df.dtypes != 'object')
number_cols = list(s[s].index)
print("Numerical variables:")
print(number_cols)
print(len(number_cols))
# Out:
# Numerical variables:
# ['PARITY', 'NUMBEROFPREVCESAREAN', 'KGINCREASEDPREGNANCY', 'PREVIOUSTERMPREGNANCIES', 'MISCARRIAGES']
# 5

# %%
for i in number_cols:
  x = m_df[i].mean()
  m_df[i].fillna(x,inplace = True)
m_df
# Out:
#       PARITY OBSTETRICRISK COMORBIDITY  NUMBEROFPREVCESAREAN  \
# 0          0             t           f              0.598906
# 1         10             f           f              0.598906
# 2         10             f           f              0.598906
# 3       1001             t           f              1.000000
# 4         10             f           f              0.598906
# ...      ...           ...         ...                   ...
# 6149       0             t           f              0.000000
# 6151       0             f           f              0.000000
# 6152       0             t           t              0.000000
# 6154      20             f           f              0.000000
# 6155    1020             t           f              0.000000
#
#       KGINCREASEDPREGNANCY STARTANTENATALCARRE ART  PREVIOUSTERMPREGNANCIES  \
# 0                       14         1ºtrimester   f                        0
# 1                        5         1ºtrimester   f                        0
# 2                       12         1ºtrimester   f                        0
# 3                       12         1ºtrimester   f                        1
# 4                       11         1ºtrimester   t                        0
# ...                    ...                 ...  ..                      ...
# 6149                     0         1ºtrimester   f                        0
# 6151                     0         2ºtrimester   f                        0
# 6152                    13         1ºtrimester   f                        0
# 6154                     0         1ºtrimester   t                        0
# 6155                     3         1ºtrimester   t                        1
#
#      AMNIOTICLIQUID  MISCARRIAGES ANESTHESIA         TYPEOFBIRTH
# 0          stained+             0          t  emergencyc-section
# 1             clear             1          t       CESprogrammed
# 2             clear             1          t                 EUT
# 3          stained+             0          t                 EUT
# 4             clear             1          t                 EUT
# ...             ...           ...        ...                 ...
# 6149    Hemorrágico             0          t                FORC
# 6151       stained+             0          t  emergencyc-section
# 6152          clear             0          t                 EUT
# 6154          clear             2          t                 EUT
# 6155          clear             2          t  emergencyc-section
#
# [3898 rows x 12 columns]

# %%
m_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3898 entries, 0 to 6155
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PARITY                   3898 non-null   int64
#  1   OBSTETRICRISK            3898 non-null   object
#  2   COMORBIDITY              3898 non-null   object
#  3   NUMBEROFPREVCESAREAN     3898 non-null   float64
#  4   KGINCREASEDPREGNANCY     3898 non-null   int64
#  5   STARTANTENATALCARRE      3898 non-null   object
#  6   ART                      3898 non-null   object
#  7   PREVIOUSTERMPREGNANCIES  3898 non-null   int64
#  8   AMNIOTICLIQUID           3898 non-null   object
#  9   MISCARRIAGES             3898 non-null   int64
#  10  ANESTHESIA               3898 non-null   object
#  11  TYPEOFBIRTH              3898 non-null   object
# dtypes: float64(1), int64(4), object(7)
# memory usage: 395.9+ KB

# %% [markdown]
# ### Checking NULL values

# %%
m_df.isnull().sum()
# Out:
# PARITY                     0
# OBSTETRICRISK              0
# COMORBIDITY                0
# NUMBEROFPREVCESAREAN       0
# KGINCREASEDPREGNANCY       0
# STARTANTENATALCARRE        0
# ART                        0
# PREVIOUSTERMPREGNANCIES    0
# AMNIOTICLIQUID             0
# MISCARRIAGES               0
# ANESTHESIA                 0
# TYPEOFBIRTH                0
# dtype: int64

# %%
m_df.TYPEOFBIRTH.unique()
# Out:
# array(['emergencyc-section', 'CESprogrammed', 'EUT', 'vacum', 'FORC',
#        'ESP', 'NALGASVAGINAL'], dtype=object)

# %%
a = m_df['TYPEOFBIRTH'].values.tolist()
s = set(a)
for x in s:
  print(x,":",a.count(x))
# Out:
# EUT : 2376
# emergencyc-section : 568
# CESprogrammed : 274
# FORC : 83
# ESP : 43
# NALGASVAGINAL : 8
# vacum : 546

# %%
m_df
# Out:
#       PARITY OBSTETRICRISK COMORBIDITY  NUMBEROFPREVCESAREAN  \
# 0          0             t           f              0.598906
# 1         10             f           f              0.598906
# 2         10             f           f              0.598906
# 3       1001             t           f              1.000000
# 4         10             f           f              0.598906
# ...      ...           ...         ...                   ...
# 6149       0             t           f              0.000000
# 6151       0             f           f              0.000000
# 6152       0             t           t              0.000000
# 6154      20             f           f              0.000000
# 6155    1020             t           f              0.000000
#
#       KGINCREASEDPREGNANCY STARTANTENATALCARRE ART  PREVIOUSTERMPREGNANCIES  \
# 0                       14         1ºtrimester   f                        0
# 1                        5         1ºtrimester   f                        0
# 2                       12         1ºtrimester   f                        0
# 3                       12         1ºtrimester   f                        1
# 4                       11         1ºtrimester   t                        0
# ...                    ...                 ...  ..                      ...
# 6149                     0         1ºtrimester   f                        0
# 6151                     0         2ºtrimester   f                        0
# 6152                    13         1ºtrimester   f                        0
# 6154                     0         1ºtrimester   t                        0
# 6155                     3         1ºtrimester   t                        1
#
#      AMNIOTICLIQUID  MISCARRIAGES ANESTHESIA         TYPEOFBIRTH
# 0          stained+             0          t  emergencyc-section
# 1             clear             1          t       CESprogrammed
# 2             clear             1          t                 EUT
# 3          stained+             0          t                 EUT
# 4             clear             1          t                 EUT
# ...             ...           ...        ...                 ...
# 6149    Hemorrágico             0          t                FORC
# 6151       stained+             0          t  emergencyc-section
# 6152          clear             0          t                 EUT
# 6154          clear             2          t                 EUT
# 6155          clear             2          t  emergencyc-section
#
# [3898 rows x 12 columns]

# %%
le = preprocessing.LabelEncoder()

#m_df.Publisher = m_df.Publisher.astype(str)

for column in m_df.columns:
    temp_new = le.fit_transform(m_df[column].astype('category'))
    m_df.drop(labels=[column], axis="columns", inplace=True)
    m_df[column] = temp_new

X = m_df.loc[:,'PARITY':'ANESTHESIA']
Y = m_df.loc[:,'TYPEOFBIRTH':]

# %%
sm = ADASYN(sampling_strategy='auto', random_state=None, n_neighbors=5, n_jobs=1)
X_adassin_1, Y_adassin_1 = sm.fit_resample(X, Y)
print(X_adassin_1.shape)
print(Y_adassin_1.shape)
# Out:
# (16412, 11)
# (16412, 1)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_adassin_1,Y_adassin_1,test_size=0.2,random_state=None)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13129 entries, 12019 to 13928
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PARITY                   13129 non-null  int64
#  1   OBSTETRICRISK            13129 non-null  int64
#  2   COMORBIDITY              13129 non-null  int64
#  3   NUMBEROFPREVCESAREAN     13129 non-null  int64
#  4   KGINCREASEDPREGNANCY     13129 non-null  int64
#  5   STARTANTENATALCARRE      13129 non-null  int64
#  6   ART                      13129 non-null  int64
#  7   PREVIOUSTERMPREGNANCIES  13129 non-null  int64
#  8   AMNIOTICLIQUID           13129 non-null  int64
#  9   MISCARRIAGES             13129 non-null  int64
#  10  ANESTHESIA               13129 non-null  int64
# dtypes: int64(11)
# memory usage: 1.2 MB

# %%
Y_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13129 entries, 12019 to 13928
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TYPEOFBIRTH  13129 non-null  int64
# dtypes: int64(1)
# memory usage: 205.1 KB

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3283 entries, 1288 to 15283
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PARITY                   3283 non-null   int64
#  1   OBSTETRICRISK            3283 non-null   int64
#  2   COMORBIDITY              3283 non-null   int64
#  3   NUMBEROFPREVCESAREAN     3283 non-null   int64
#  4   KGINCREASEDPREGNANCY     3283 non-null   int64
#  5   STARTANTENATALCARRE      3283 non-null   int64
#  6   ART                      3283 non-null   int64
#  7   PREVIOUSTERMPREGNANCIES  3283 non-null   int64
#  8   AMNIOTICLIQUID           3283 non-null   int64
#  9   MISCARRIAGES             3283 non-null   int64
#  10  ANESTHESIA               3283 non-null   int64
# dtypes: int64(11)
# memory usage: 307.8 KB

# %%
Y_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3283 entries, 1288 to 15283
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TYPEOFBIRTH  3283 non-null   int64
# dtypes: int64(1)
# memory usage: 51.3 KB

# %%
model = DecisionTreeClassifier(criterion = 'entropy')
model.fit(X_train,Y_train)
y_pred = model.predict(X_test)
print(accuracy_score(Y_test,y_pred))
print(precision_score(Y_test,y_pred,pos_label='positive',average='weighted'))
print(recall_score(Y_test,y_pred,pos_label='positive',average='micro'))

m_dt_f1 = f1_score(Y_test, y_pred,average='micro')

print(m_dt_f1)
# Out:
# 0.6893085592445933
# 0.6830972838693675
# 0.6893085592445933
# 0.6893085592445933
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,

# %%
RFC = RandomForestClassifier()
RFC.fit(X_train, Y_train.values.ravel())
y_pred = RFC.predict(X_test)
print(accuracy_score(Y_test,y_pred))
print(precision_score(Y_test,y_pred,pos_label='positive',average='weighted'))
print(recall_score(Y_test,y_pred,pos_label='positive',average='micro'))
print(f1_score(Y_test, y_pred,average='micro'))

m_rfc_f1 = f1_score(Y_test, y_pred,average='micro')

print(m_rfc_f1)
# Out:
# 0.7203777033201341
# 0.7182595302618088
# 0.7203777033201341
# 0.720377703320134
# 0.720377703320134
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,

# %%
svc = SVC(gamma = 0.001, C = 1000)
y_pred = svc.fit(X_train, Y_train.values.ravel()).predict(X_test)
print(accuracy_score(Y_test,y_pred))
print(precision_score(Y_test,y_pred,pos_label='positive',average='weighted'))
print(recall_score(Y_test,y_pred,pos_label='positive',average='micro'))

m_svc_f1 = f1_score(Y_test, y_pred,average='micro')

print(m_svc_f1)
# Out:
# 0.5418824246116357
# 0.5419218940894711
# 0.5418824246116357
# 0.5418824246116357
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,

# %%
K = []
training = []
test = []
scores = {}
  
for k in range(2, 21):
    clf = KNeighborsClassifier(n_neighbors = k)
    clf.fit(X_train, Y_train.values.ravel())
  
    training_score = clf.score(X_train, Y_train)
    test_score = clf.score(X_test, Y_test)
    K.append(k)
  
    training.append(training_score)
    test.append(test_score)
    scores[k] = [training_score, test_score]
for keys, values in scores.items():
    print(keys, ':', values)
# Out:
# 2 : [0.7182572930154619, 0.6198598842522084]
# 3 : [0.7231319978673166, 0.6472738349070971]
# 4 : [0.7162007769060857, 0.6454462381967713]
# 5 : [0.7143727625866403, 0.6405726469692354]
# 6 : [0.6985299718181126, 0.6210782820590923]
# 7 : [0.691674918120192, 0.6244288760280231]
# 8 : [0.690380074643918, 0.6256472738349071]
# 9 : [0.6819255084164826, 0.6207736826073713]
# 10 : [0.6756036255617336, 0.6226012793176973]
# 11 : [0.6710335897631198, 0.6195552848004874]
# 12 : [0.6646355396450605, 0.6152908924763936]
# 13 : [0.66113184553279, 0.6149862930246726]
# 14 : [0.6526772793053546, 0.6119402985074627]
# 15 : [0.6479549089801203, 0.6070667072799268]
# 16 : [0.6425470332850941, 0.6000609198903442]
# 17 : [0.6395003427526849, 0.5961011270179714]
# 18 : [0.631883616421662, 0.5887907401766677]
# 19 : [0.6290654276791835, 0.5842217484008528]
# 20 : [0.6248762281971209, 0.5790435577215961]

# %%
model = KNeighborsClassifier(n_neighbors=2,weights='distance',p=1)
model.fit(X_train,Y_train.values.ravel())
y_pred = model.predict(X_test)
print(accuracy_score(Y_test,y_pred))
print(precision_score(Y_test,y_pred,pos_label='positive',average='weighted'))
print(recall_score(Y_test,y_pred,pos_label='positive',average='micro'))

m_knn_f1 = f1_score(Y_test, y_pred,average='micro')

print(m_knn_f1)
# Out:
# 0.6405726469692354
# 0.6443932437600132
# 0.6405726469692354
# 0.6405726469692354
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,

# %%
estimators = [('rf', RandomForestClassifier()),('svr', make_pipeline(StandardScaler(),LinearSVC())),('dt',DecisionTreeClassifier(criterion = 'entropy')),('knn',KNeighborsClassifier(n_neighbors=2,weights='distance',p=1))]
clf = StackingClassifier(estimators=estimators, final_estimator=LogisticRegression())
clf.fit(X_train, Y_train.values.ravel())
y_pred = clf.predict(X_test)
print(accuracy_score(Y_test,y_pred))
print(precision_score(Y_test,y_pred,pos_label='positive',average='weighted'))
print(recall_score(Y_test,y_pred,pos_label='positive',average='micro'))

m_sc_f1 = f1_score(Y_test, y_pred,average='micro')

print(m_sc_f1)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# 0.721291501675297
# 0.719371512191215
# 0.721291501675297
# 0.721291501675297
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,

# %%
l_df = c_df[['GESTAGIONALAGE','HEIGHT','WEIGHT','BMI','AGE','CARDIOTOCOGRAPHY','MATERNALEDUCATION','SUBSTANCEABUSE','SMOKING','ALCOHOL','TYPEOFBIRTH']]

# %% [markdown]
# ### Checking duplicates

# %%
l_df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6152    False
# 6153    False
# 6154    False
# 6155    False
# 6156    False
# Length: 6157, dtype: bool

# %%
l_df.duplicated().sum()
# Out:
# 55

# %% [markdown]
# ### Drop duplicate records

# %%
l_df = l_df.drop_duplicates()
l_df
# Out:
#       GESTAGIONALAGE  HEIGHT  WEIGHT    BMI  AGE CARDIOTOCOGRAPHY  \
# 0                 37    1.58    70.0  28.04   30       continuous
# 1                 38    1.61    79.0  30.48   38       continuous
# 2                 39    1.56    72.0  29.59   25       continuous
# 3                 40    1.62    54.0  20.58   31       continuous
# 4                 41    1.47    51.0  23.60   28       continuous
# ...              ...     ...     ...    ...  ...              ...
# 6152              35    1.56    49.0  20.00   35       continuous
# 6153              40    1.64    59.0  21.51   29       continuous
# 6154              39    1.59    64.0  20.00   39    discontinuous
# 6155              39    1.48    50.0  23.28   41       continuous
# 6156              38    1.65    75.2  24.00   32    discontinuous
#
#      MATERNALEDUCATION SUBSTANCEABUSE SMOKING ALCOHOL         TYPEOFBIRTH
# 0            secondary              f       f       f  emergencyc-section
# 1            secondary              f       f       f       CESprogrammed
# 2            secondary              f       f       f                 EUT
# 3            secondary              f       f       f                 EUT
# 4            secondary              f       f       f                 EUT
# ...                ...            ...     ...     ...                 ...
# 6152         secondary              f       f       f                 EUT
# 6153         secondary              f       f       f                 EUT
# 6154         secondary              f       f       t                 EUT
# 6155           primary              f       f       f  emergencyc-section
# 6156       Sinestudios              f       f       f                 EUT
#
# [6102 rows x 11 columns]

# %%
l_df = l_df.replace(r'^\s*$', np.nan, regex=True)

# %% [markdown]
# ### Handling missing values of categorical attributes by mode

# %%
s = (l_df.dtypes == 'object')
#print(s)
#print(s[s])
object_cols = list(s[s].index)
print("Categorical variables:")
print(object_cols)
print(len(object_cols))
# Out:
# Categorical variables:
# ['CARDIOTOCOGRAPHY', 'MATERNALEDUCATION', 'SUBSTANCEABUSE', 'SMOKING', 'ALCOHOL', 'TYPEOFBIRTH']
# 6

# %%
for i in object_cols:
  x = l_df[i].mode()[0]
  l_df[i].fillna(x,inplace = True)
l_df
# Out:
#       GESTAGIONALAGE  HEIGHT  WEIGHT    BMI  AGE CARDIOTOCOGRAPHY  \
# 0                 37    1.58    70.0  28.04   30       continuous
# 1                 38    1.61    79.0  30.48   38       continuous
# 2                 39    1.56    72.0  29.59   25       continuous
# 3                 40    1.62    54.0  20.58   31       continuous
# 4                 41    1.47    51.0  23.60   28       continuous
# ...              ...     ...     ...    ...  ...              ...
# 6152              35    1.56    49.0  20.00   35       continuous
# 6153              40    1.64    59.0  21.51   29       continuous
# 6154              39    1.59    64.0  20.00   39    discontinuous
# 6155              39    1.48    50.0  23.28   41       continuous
# 6156              38    1.65    75.2  24.00   32    discontinuous
#
#      MATERNALEDUCATION SUBSTANCEABUSE SMOKING ALCOHOL         TYPEOFBIRTH
# 0            secondary              f       f       f  emergencyc-section
# 1            secondary              f       f       f       CESprogrammed
# 2            secondary              f       f       f                 EUT
# 3            secondary              f       f       f                 EUT
# 4            secondary              f       f       f                 EUT
# ...                ...            ...     ...     ...                 ...
# 6152         secondary              f       f       f                 EUT
# 6153         secondary              f       f       f                 EUT
# 6154         secondary              f       f       t                 EUT
# 6155           primary              f       f       f  emergencyc-section
# 6156       Sinestudios              f       f       f                 EUT
#
# [6102 rows x 11 columns]

# %% [markdown]
# ### Handling missing values of Numerical attributes using mean

# %%
s = (l_df.dtypes != 'object')
number_cols = list(s[s].index)
print("Numerical variables:")
print(number_cols)
print(len(number_cols))
# Out:
# Numerical variables:
# ['GESTAGIONALAGE', 'HEIGHT', 'WEIGHT', 'BMI', 'AGE']
# 5

# %%
for i in number_cols:
  x = l_df[i].mean()
  l_df[i].fillna(x,inplace = True)
l_df
# Out:
#       GESTAGIONALAGE  HEIGHT  WEIGHT    BMI  AGE CARDIOTOCOGRAPHY  \
# 0                 37    1.58    70.0  28.04   30       continuous
# 1                 38    1.61    79.0  30.48   38       continuous
# 2                 39    1.56    72.0  29.59   25       continuous
# 3                 40    1.62    54.0  20.58   31       continuous
# 4                 41    1.47    51.0  23.60   28       continuous
# ...              ...     ...     ...    ...  ...              ...
# 6152              35    1.56    49.0  20.00   35       continuous
# 6153              40    1.64    59.0  21.51   29       continuous
# 6154              39    1.59    64.0  20.00   39    discontinuous
# 6155              39    1.48    50.0  23.28   41       continuous
# 6156              38    1.65    75.2  24.00   32    discontinuous
#
#      MATERNALEDUCATION SUBSTANCEABUSE SMOKING ALCOHOL         TYPEOFBIRTH
# 0            secondary              f       f       f  emergencyc-section
# 1            secondary              f       f       f       CESprogrammed
# 2            secondary              f       f       f                 EUT
# 3            secondary              f       f       f                 EUT
# 4            secondary              f       f       f                 EUT
# ...                ...            ...     ...     ...                 ...
# 6152         secondary              f       f       f                 EUT
# 6153         secondary              f       f       f                 EUT
# 6154         secondary              f       f       t                 EUT
# 6155           primary              f       f       f  emergencyc-section
# 6156       Sinestudios              f       f       f                 EUT
#
# [6102 rows x 11 columns]

# %%
l_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6102 entries, 0 to 6156
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GESTAGIONALAGE     6102 non-null   int64
#  1   HEIGHT             6102 non-null   float64
#  2   WEIGHT             6102 non-null   float64
#  3   BMI                6102 non-null   float64
#  4   AGE                6102 non-null   int64
#  5   CARDIOTOCOGRAPHY   6102 non-null   object
#  6   MATERNALEDUCATION  6102 non-null   object
#  7   SUBSTANCEABUSE     6102 non-null   object
#  8   SMOKING            6102 non-null   object
#  9   ALCOHOL            6102 non-null   object
#  10  TYPEOFBIRTH        6102 non-null   object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 572.1+ KB

# %% [markdown]
# ### Checking NULL values

# %%
l_df.isnull().sum()
# Out:
# GESTAGIONALAGE       0
# HEIGHT               0
# WEIGHT               0
# BMI                  0
# AGE                  0
# CARDIOTOCOGRAPHY     0
# MATERNALEDUCATION    0
# SUBSTANCEABUSE       0
# SMOKING              0
# ALCOHOL              0
# TYPEOFBIRTH          0
# dtype: int64

# %%
l_df.TYPEOFBIRTH.unique()
# Out:
# array(['emergencyc-section', 'CESprogrammed', 'EUT', 'vacum', 'FORC',
#        'ESP', 'NALGASVAGINAL'], dtype=object)

# %%
a = l_df['TYPEOFBIRTH'].values.tolist()
s = set(a)
for x in s:
  print(x,":",a.count(x))
# Out:
# EUT : 4192
# emergencyc-section : 684
# CESprogrammed : 324
# FORC : 86
# ESP : 44
# NALGASVAGINAL : 8
# vacum : 764

# %%
l_df
# Out:
#       GESTAGIONALAGE  HEIGHT  WEIGHT    BMI  AGE CARDIOTOCOGRAPHY  \
# 0                 37    1.58    70.0  28.04   30       continuous
# 1                 38    1.61    79.0  30.48   38       continuous
# 2                 39    1.56    72.0  29.59   25       continuous
# 3                 40    1.62    54.0  20.58   31       continuous
# 4                 41    1.47    51.0  23.60   28       continuous
# ...              ...     ...     ...    ...  ...              ...
# 6152              35    1.56    49.0  20.00   35       continuous
# 6153              40    1.64    59.0  21.51   29       continuous
# 6154              39    1.59    64.0  20.00   39    discontinuous
# 6155              39    1.48    50.0  23.28   41       continuous
# 6156              38    1.65    75.2  24.00   32    discontinuous
#
#      MATERNALEDUCATION SUBSTANCEABUSE SMOKING ALCOHOL         TYPEOFBIRTH
# 0            secondary              f       f       f  emergencyc-section
# 1            secondary              f       f       f       CESprogrammed
# 2            secondary              f       f       f                 EUT
# 3            secondary              f       f       f                 EUT
# 4            secondary              f       f       f                 EUT
# ...                ...            ...     ...     ...                 ...
# 6152         secondary              f       f       f                 EUT
# 6153         secondary              f       f       f                 EUT
# 6154         secondary              f       f       t                 EUT
# 6155           primary              f       f       f  emergencyc-section
# 6156       Sinestudios              f       f       f                 EUT
#
# [6102 rows x 11 columns]

# %%
le = preprocessing.LabelEncoder()

#l_df.Publisher = l_df.Publisher.astype(str)

for column in l_df.columns:
    temp_new = le.fit_transform(l_df[column].astype('category'))
    l_df.drop(labels=[column], axis="columns", inplace=True)
    l_df[column] = temp_new

X = l_df.loc[:,'GESTAGIONALAGE':'ALCOHOL']
Y = l_df.loc[:,'TYPEOFBIRTH':]

# %%
sm = ADASYN(sampling_strategy='auto', random_state=None, n_neighbors=5, n_jobs=1)
X_adassin_1, Y_adassin_1 = sm.fit_resample(X, Y)
print(X_adassin_1.shape)
print(Y_adassin_1.shape)
# Out:
# (29416, 10)
# (29416, 1)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_adassin_1,Y_adassin_1,test_size=0.2,random_state=None)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23532 entries, 21726 to 14815
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GESTAGIONALAGE     23532 non-null  int64
#  1   HEIGHT             23532 non-null  int64
#  2   WEIGHT             23532 non-null  int64
#  3   BMI                23532 non-null  int64
#  4   AGE                23532 non-null  int64
#  5   CARDIOTOCOGRAPHY   23532 non-null  int64
#  6   MATERNALEDUCATION  23532 non-null  int64
#  7   SUBSTANCEABUSE     23532 non-null  int64
#  8   SMOKING            23532 non-null  int64
#  9   ALCOHOL            23532 non-null  int64
# dtypes: int64(10)
# memory usage: 2.0 MB

# %%
Y_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23532 entries, 21726 to 14815
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TYPEOFBIRTH  23532 non-null  int64
# dtypes: int64(1)
# memory usage: 367.7 KB

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5884 entries, 19117 to 5379
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GESTAGIONALAGE     5884 non-null   int64
#  1   HEIGHT             5884 non-null   int64
#  2   WEIGHT             5884 non-null   int64
#  3   BMI                5884 non-null   int64
#  4   AGE                5884 non-null   int64
#  5   CARDIOTOCOGRAPHY   5884 non-null   int64
#  6   MATERNALEDUCATION  5884 non-null   int64
#  7   SUBSTANCEABUSE     5884 non-null   int64
#  8   SMOKING            5884 non-null   int64
#  9   ALCOHOL            5884 non-null   int64
# dtypes: int64(10)
# memory usage: 505.7 KB

# %%
Y_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5884 entries, 19117 to 5379
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TYPEOFBIRTH  5884 non-null   int64
# dtypes: int64(1)
# memory usage: 91.9 KB

# %%
model = DecisionTreeClassifier(criterion = 'entropy')
model.fit(X_train,Y_train)
y_pred = model.predict(X_test)
print(accuracy_score(Y_test,y_pred))
print(precision_score(Y_test,y_pred,pos_label='positive',average='weighted'))
print(recall_score(Y_test,y_pred,pos_label='positive',average='micro'))

l_dt_f1 = f1_score(Y_test, y_pred,average='micro')

print(l_dt_f1)
# Out:
# 0.7834806254248811
# 0.7726526560699748
# 0.7834806254248811
# 0.7834806254248811
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,

# %%
RFC = RandomForestClassifier()
RFC.fit(X_train, Y_train.values.ravel())
y_pred = RFC.predict(X_test)
print(accuracy_score(Y_test,y_pred))
print(precision_score(Y_test,y_pred,pos_label='positive',average='weighted'))
print(recall_score(Y_test,y_pred,pos_label='positive',average='micro'))

l_rfc_f1 = f1_score(Y_test, y_pred,average='micro')

print(l_rfc_f1)
# Out:
# 0.8475526852481305
# 0.84238350471728
# 0.8475526852481305
# 0.8475526852481305
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,

# %%
svc = SVC(gamma = 0.001, C = 1000)
y_pred = svc.fit(X_train, Y_train.values.ravel()).predict(X_test)
print(accuracy_score(Y_test,y_pred))
print(precision_score(Y_test,y_pred,pos_label='positive',average='weighted'))
print(recall_score(Y_test,y_pred,pos_label='positive',average='micro'))

l_svc_f1 = f1_score(Y_test, y_pred,average='micro')

print(l_svc_f1)
# Out:
# 0.8453433038749151
# 0.8379117450955752
# 0.8453433038749151
# 0.8453433038749151
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,

# %%
K = []
training = []
test = []
scores = {}
  
for k in range(2, 21):
    clf = KNeighborsClassifier(n_neighbors = k)
    clf.fit(X_train, Y_train.values.ravel())
  
    training_score = clf.score(X_train, Y_train)
    test_score = clf.score(X_test, Y_test)
    K.append(k)
  
    training.append(training_score)
    test.append(test_score)
    scores[k] = [training_score, test_score]
for keys, values in scores.items():
    print(keys, ':', values)
# Out:
# 2 : [0.9089750127485976, 0.7491502379333786]
# 3 : [0.8725990141084481, 0.7457511896668932]
# 4 : [0.8374128845826959, 0.7255268524813052]
# 5 : [0.8122556518782934, 0.7092114208021754]
# 6 : [0.7862060173380928, 0.690006798096533]
# 7 : [0.7676780554139044, 0.6806594153636981]
# 8 : [0.7462179160292368, 0.668592794017675]
# 9 : [0.7340642529321775, 0.657205982324949]
# 10 : [0.7212731599524053, 0.6497280761386812]
# 11 : [0.709374468808431, 0.6390210740992522]
# 12 : [0.6972208057113718, 0.6283140720598233]
# 13 : [0.6830273669896312, 0.6227056424201224]
# 14 : [0.6744008159102499, 0.6092794017675051]
# 15 : [0.6629695733469319, 0.6050305914343984]
# 16 : [0.6534931157572667, 0.5951733514615908]
# 17 : [0.6432092469828319, 0.5849762066621346]
# 18 : [0.6366224715281319, 0.5761386811692726]
# 19 : [0.6314805371409145, 0.5705302515295717]
# 20 : [0.6244688084310726, 0.5671312032630863]

# %%
model = KNeighborsClassifier(n_neighbors=2,weights='distance',p=1)
model.fit(X_train,Y_train.values.ravel())
y_pred = model.predict(X_test)
print(accuracy_score(Y_test,y_pred))
print(precision_score(Y_test,y_pred,pos_label='positive',average='weighted'))
print(recall_score(Y_test,y_pred,pos_label='positive',average='micro'))

l_knn_f1 = f1_score(Y_test, y_pred,average='micro')

print(l_knn_f1)
# Out:
# 0.8223997280761387
# 0.8146956587094438
# 0.8223997280761387
# 0.8223997280761387
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,

# %%
estimators = [('rf', RandomForestClassifier()),('svr', make_pipeline(StandardScaler(),LinearSVC())),('dt',DecisionTreeClassifier(criterion = 'entropy')),('knn',KNeighborsClassifier(n_neighbors=2,weights='distance',p=1))]
clf = StackingClassifier(estimators=estimators, final_estimator=LogisticRegression())
clf.fit(X_train, Y_train.values.ravel())
y_pred = clf.predict(X_test)
print(accuracy_score(Y_test,y_pred))
print(precision_score(Y_test,y_pred,pos_label='positive',average='weighted'))
print(recall_score(Y_test,y_pred,pos_label='positive',average='micro'))

l_sc_f1 = f1_score(Y_test, y_pred,average='micro')

print(l_sc_f1)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# 0.881883072739633
# 0.881385663813387
# 0.881883072739633
# 0.881883072739633
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,

# %% [markdown]
# ### Dataset after feature extraction

# %%
hm_df = c_df[['PREVIOUSCESAREAN','COMPLICATIONS','ROBSONGROUP','ARTMODE','PREVIOUSPRETERMPREGNANCIES','AMNIOCENTESIS','PREINDUCTION','INDUCTION',
        'EPISIOTOMY','OXYTOCIN','FetalINTRAPARTUMpH','PARITY','OBSTETRICRISK','COMORBIDITY','NUMBEROFPREVCESAREAN','KGINCREASEDPREGNANCY','STARTANTENATALCARRE',
        'ART','PREVIOUSTERMPREGNANCIES','AMNIOTICLIQUID','MISCARRIAGES','ANESTHESIA','TYPEOFBIRTH']]

# %% [markdown]
# ### Checking duplicates

# %%
hm_df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6152    False
# 6153     True
# 6154    False
# 6155    False
# 6156     True
# Length: 6157, dtype: bool

# %%
hm_df.duplicated().sum()
# Out:
# 896

# %% [markdown]
# ### Drop duplicate records

# %%
hm_df = hm_df.drop_duplicates()
hm_df
# Out:
#      PREVIOUSCESAREAN COMPLICATIONS ROBSONGROUP ARTMODE  \
# 0                   f             f     group2a     NaN
# 1                   f             f      group6     NaN
# 2                   f             f      group1     NaN
# 3                   t             f      group5     NaN
# 4                   f             f      group1     FIV
# ...               ...           ...         ...     ...
# 6150                f             f      group1     NaN
# 6151                f             f     group2a     NaN
# 6152                f             f      group8     NaN
# 6154                f             f      group1     IAD
# 6155                f             f     group2a     FIV
#
#       PREVIOUSPRETERMPREGNANCIES AMNIOCENTESIS PREINDUCTION INDUCTION  \
# 0                              0             f            t         t
# 1                              0             f            f         f
# 2                              0             f            f         f
# 3                              0             f            f         f
# 4                              0             f            f         f
# ...                          ...           ...          ...       ...
# 6150                           0             f            f         f
# 6151                           0             f            f         t
# 6152                           0             t            f         f
# 6154                           0             f            f         f
# 6155                           0             f            f         t
#
#      EPISIOTOMY OXYTOCIN  ... COMORBIDITY  NUMBEROFPREVCESAREAN  \
# 0           NaN        t  ...           f                   NaN
# 1           NaN        f  ...           f                   NaN
# 2             f        t  ...           f                   NaN
# 3             f        f  ...           f                   1.0
# 4             f        t  ...           f                   NaN
# ...         ...      ...  ...         ...                   ...
# 6150          f        t  ...           f                   0.0
# 6151          f        f  ...           f                   0.0
# 6152          t        f  ...           t                   0.0
# 6154          f        f  ...           f                   0.0
# 6155          f        t  ...           f                   0.0
#
#      KGINCREASEDPREGNANCY STARTANTENATALCARRE  ART  PREVIOUSTERMPREGNANCIES  \
# 0                      14         1ºtrimester    f                        0
# 1                       5         1ºtrimester    f                        0
# 2                      12         1ºtrimester    f                        0
# 3                      12         1ºtrimester    f                        1
# 4                      11         1ºtrimester    t                        0
# ...                   ...                 ...  ...                      ...
# 6150                    0         1ºtrimester    f                        0
# 6151                    0         2ºtrimester    f                        0
# 6152                   13         1ºtrimester    f                        0
# 6154                    0         1ºtrimester    t                        0
# 6155                    3         1ºtrimester    t                        1
#
#      AMNIOTICLIQUID MISCARRIAGES  ANESTHESIA         TYPEOFBIRTH
# 0          stained+            0           t  emergencyc-section
# 1             clear            1           t       CESprogrammed
# 2             clear            1           t                 EUT
# 3          stained+            0           t                 EUT
# 4             clear            1           t                 EUT
# ...             ...          ...         ...                 ...
# 6150       stained+            0           t  emergencyc-section
# 6151       stained+            0           t  emergencyc-section
# 6152          clear            0           t                 EUT
# 6154          clear            2           t                 EUT
# 6155          clear            2           t  emergencyc-section
#
# [5261 rows x 23 columns]

# %%
hm_df = hm_df.replace(r'^\s*$', np.nan, regex=True)

# %% [markdown]
# ### Handling missing values of categorical attributes by mode

# %%
s = (hm_df.dtypes == 'object')
#print(s)
#print(s[s])
object_cols = list(s[s].index)
print("Categorical variables:")
print(object_cols)
print(len(object_cols))
# Out:
# Categorical variables:
# ['PREVIOUSCESAREAN', 'COMPLICATIONS', 'ROBSONGROUP', 'ARTMODE', 'AMNIOCENTESIS', 'PREINDUCTION', 'INDUCTION', 'EPISIOTOMY', 'OXYTOCIN', 'FetalINTRAPARTUMpH', 'OBSTETRICRISK', 'COMORBIDITY', 'STARTANTENATALCARRE', 'ART', 'AMNIOTICLIQUID', 'ANESTHESIA', 'TYPEOFBIRTH']
# 17

# %%
for i in object_cols:
  x = hm_df[i].mode()[0]
  hm_df[i].fillna(x,inplace = True)
hm_df
# Out:
#      PREVIOUSCESAREAN COMPLICATIONS ROBSONGROUP ARTMODE  \
# 0                   f             f     group2a     FIV
# 1                   f             f      group6     FIV
# 2                   f             f      group1     FIV
# 3                   t             f      group5     FIV
# 4                   f             f      group1     FIV
# ...               ...           ...         ...     ...
# 6150                f             f      group1     FIV
# 6151                f             f     group2a     FIV
# 6152                f             f      group8     FIV
# 6154                f             f      group1     IAD
# 6155                f             f     group2a     FIV
#
#       PREVIOUSPRETERMPREGNANCIES AMNIOCENTESIS PREINDUCTION INDUCTION  \
# 0                              0             f            t         t
# 1                              0             f            f         f
# 2                              0             f            f         f
# 3                              0             f            f         f
# 4                              0             f            f         f
# ...                          ...           ...          ...       ...
# 6150                           0             f            f         f
# 6151                           0             f            f         t
# 6152                           0             t            f         f
# 6154                           0             f            f         f
# 6155                           0             f            f         t
#
#      EPISIOTOMY OXYTOCIN  ... COMORBIDITY  NUMBEROFPREVCESAREAN  \
# 0             f        t  ...           f                   NaN
# 1             f        f  ...           f                   NaN
# 2             f        t  ...           f                   NaN
# 3             f        f  ...           f                   1.0
# 4             f        t  ...           f                   NaN
# ...         ...      ...  ...         ...                   ...
# 6150          f        t  ...           f                   0.0
# 6151          f        f  ...           f                   0.0
# 6152          t        f  ...           t                   0.0
# 6154          f        f  ...           f                   0.0
# 6155          f        t  ...           f                   0.0
#
#      KGINCREASEDPREGNANCY STARTANTENATALCARRE  ART  PREVIOUSTERMPREGNANCIES  \
# 0                      14         1ºtrimester    f                        0
# 1                       5         1ºtrimester    f                        0
# 2                      12         1ºtrimester    f                        0
# 3                      12         1ºtrimester    f                        1
# 4                      11         1ºtrimester    t                        0
# ...                   ...                 ...  ...                      ...
# 6150                    0         1ºtrimester    f                        0
# 6151                    0         2ºtrimester    f                        0
# 6152                   13         1ºtrimester    f                        0
# 6154                    0         1ºtrimester    t                        0
# 6155                    3         1ºtrimester    t                        1
#
#      AMNIOTICLIQUID MISCARRIAGES  ANESTHESIA         TYPEOFBIRTH
# 0          stained+            0           t  emergencyc-section
# 1             clear            1           t       CESprogrammed
# 2             clear            1           t                 EUT
# 3          stained+            0           t                 EUT
# 4             clear            1           t                 EUT
# ...             ...          ...         ...                 ...
# 6150       stained+            0           t  emergencyc-section
# 6151       stained+            0           t  emergencyc-section
# 6152          clear            0           t                 EUT
# 6154          clear            2           t                 EUT
# 6155          clear            2           t  emergencyc-section
#
# [5261 rows x 23 columns]

# %% [markdown]
# ### Handling missing values of Numerical attributes using mean

# %%
s = (hm_df.dtypes != 'object')
number_cols = list(s[s].index)
print("Numerical variables:")
print(number_cols)
print(len(number_cols))
# Out:
# Numerical variables:
# ['PREVIOUSPRETERMPREGNANCIES', 'PARITY', 'NUMBEROFPREVCESAREAN', 'KGINCREASEDPREGNANCY', 'PREVIOUSTERMPREGNANCIES', 'MISCARRIAGES']
# 6

# %%
for i in number_cols:
  x = hm_df[i].mean()
  hm_df[i].fillna(x,inplace = True)
hm_df
# Out:
#      PREVIOUSCESAREAN COMPLICATIONS ROBSONGROUP ARTMODE  \
# 0                   f             f     group2a     FIV
# 1                   f             f      group6     FIV
# 2                   f             f      group1     FIV
# 3                   t             f      group5     FIV
# 4                   f             f      group1     FIV
# ...               ...           ...         ...     ...
# 6150                f             f      group1     FIV
# 6151                f             f     group2a     FIV
# 6152                f             f      group8     FIV
# 6154                f             f      group1     IAD
# 6155                f             f     group2a     FIV
#
#       PREVIOUSPRETERMPREGNANCIES AMNIOCENTESIS PREINDUCTION INDUCTION  \
# 0                              0             f            t         t
# 1                              0             f            f         f
# 2                              0             f            f         f
# 3                              0             f            f         f
# 4                              0             f            f         f
# ...                          ...           ...          ...       ...
# 6150                           0             f            f         f
# 6151                           0             f            f         t
# 6152                           0             t            f         f
# 6154                           0             f            f         f
# 6155                           0             f            f         t
#
#      EPISIOTOMY OXYTOCIN  ... COMORBIDITY  NUMBEROFPREVCESAREAN  \
# 0             f        t  ...           f              0.560456
# 1             f        f  ...           f              0.560456
# 2             f        t  ...           f              0.560456
# 3             f        f  ...           f              1.000000
# 4             f        t  ...           f              0.560456
# ...         ...      ...  ...         ...                   ...
# 6150          f        t  ...           f              0.000000
# 6151          f        f  ...           f              0.000000
# 6152          t        f  ...           t              0.000000
# 6154          f        f  ...           f              0.000000
# 6155          f        t  ...           f              0.000000
#
#      KGINCREASEDPREGNANCY STARTANTENATALCARRE  ART  PREVIOUSTERMPREGNANCIES  \
# 0                      14         1ºtrimester    f                        0
# 1                       5         1ºtrimester    f                        0
# 2                      12         1ºtrimester    f                        0
# 3                      12         1ºtrimester    f                        1
# 4                      11         1ºtrimester    t                        0
# ...                   ...                 ...  ...                      ...
# 6150                    0         1ºtrimester    f                        0
# 6151                    0         2ºtrimester    f                        0
# 6152                   13         1ºtrimester    f                        0
# 6154                    0         1ºtrimester    t                        0
# 6155                    3         1ºtrimester    t                        1
#
#      AMNIOTICLIQUID MISCARRIAGES  ANESTHESIA         TYPEOFBIRTH
# 0          stained+            0           t  emergencyc-section
# 1             clear            1           t       CESprogrammed
# 2             clear            1           t                 EUT
# 3          stained+            0           t                 EUT
# 4             clear            1           t                 EUT
# ...             ...          ...         ...                 ...
# 6150       stained+            0           t  emergencyc-section
# 6151       stained+            0           t  emergencyc-section
# 6152          clear            0           t                 EUT
# 6154          clear            2           t                 EUT
# 6155          clear            2           t  emergencyc-section
#
# [5261 rows x 23 columns]

# %%
hm_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5261 entries, 0 to 6155
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PREVIOUSCESAREAN            5261 non-null   object
#  1   COMPLICATIONS               5261 non-null   object
#  2   ROBSONGROUP                 5261 non-null   object
#  3   ARTMODE                     5261 non-null   object
#  4   PREVIOUSPRETERMPREGNANCIES  5261 non-null   int64
#  5   AMNIOCENTESIS               5261 non-null   object
#  6   PREINDUCTION                5261 non-null   object
#  7   INDUCTION                   5261 non-null   object
#  8   EPISIOTOMY                  5261 non-null   object
#  9   OXYTOCIN                    5261 non-null   object
#  10  FetalINTRAPARTUMpH          5261 non-null   object
#  11  PARITY                      5261 non-null   int64
#  12  OBSTETRICRISK               5261 non-null   object
#  13  COMORBIDITY                 5261 non-null   object
#  14  NUMBEROFPREVCESAREAN        5261 non-null   float64
#  15  KGINCREASEDPREGNANCY        5261 non-null   int64
#  16  STARTANTENATALCARRE         5261 non-null   object
#  17  ART                         5261 non-null   object
#  18  PREVIOUSTERMPREGNANCIES     5261 non-null   int64
#  19  AMNIOTICLIQUID              5261 non-null   object
#  20  MISCARRIAGES                5261 non-null   int64
#  21  ANESTHESIA                  5261 non-null   object
#  22  TYPEOFBIRTH                 5261 non-null   object
# dtypes: float64(1), int64(5), object(17)
# memory usage: 986.4+ KB

# %% [markdown]
# ### Checking NULL values

# %%
hm_df.isnull().sum()
# Out:
# PREVIOUSCESAREAN              0
# COMPLICATIONS                 0
# ROBSONGROUP                   0
# ARTMODE                       0
# PREVIOUSPRETERMPREGNANCIES    0
# AMNIOCENTESIS                 0
# PREINDUCTION                  0
# INDUCTION                     0
# EPISIOTOMY                    0
# OXYTOCIN                      0
# FetalINTRAPARTUMpH            0
# PARITY                        0
# OBSTETRICRISK                 0
# COMORBIDITY                   0
# NUMBEROFPREVCESAREAN          0
# KGINCREASEDPREGNANCY          0
# STARTANTENATALCARRE           0
# ART                           0
# PREVIOUSTERMPREGNANCIES       0
# AMNIOTICLIQUID                0
# MISCARRIAGES                  0
# ANESTHESIA                    0
# TYPEOFBIRTH                   0
# dtype: int64

# %%
hm_df.TYPEOFBIRTH.unique()
# Out:
# array(['emergencyc-section', 'CESprogrammed', 'EUT', 'vacum', 'FORC',
#        'ESP', 'NALGASVAGINAL'], dtype=object)

# %%
a = hm_df['TYPEOFBIRTH'].values.tolist()
s = set(a)
for x in s:
  print(x,":",a.count(x))
# Out:
# EUT : 3431
# emergencyc-section : 667
# CESprogrammed : 302
# FORC : 87
# ESP : 44
# NALGASVAGINAL : 8
# vacum : 722

# %%
hm_df
# Out:
#      PREVIOUSCESAREAN COMPLICATIONS ROBSONGROUP ARTMODE  \
# 0                   f             f     group2a     FIV
# 1                   f             f      group6     FIV
# 2                   f             f      group1     FIV
# 3                   t             f      group5     FIV
# 4                   f             f      group1     FIV
# ...               ...           ...         ...     ...
# 6150                f             f      group1     FIV
# 6151                f             f     group2a     FIV
# 6152                f             f      group8     FIV
# 6154                f             f      group1     IAD
# 6155                f             f     group2a     FIV
#
#       PREVIOUSPRETERMPREGNANCIES AMNIOCENTESIS PREINDUCTION INDUCTION  \
# 0                              0             f            t         t
# 1                              0             f            f         f
# 2                              0             f            f         f
# 3                              0             f            f         f
# 4                              0             f            f         f
# ...                          ...           ...          ...       ...
# 6150                           0             f            f         f
# 6151                           0             f            f         t
# 6152                           0             t            f         f
# 6154                           0             f            f         f
# 6155                           0             f            f         t
#
#      EPISIOTOMY OXYTOCIN  ... COMORBIDITY  NUMBEROFPREVCESAREAN  \
# 0             f        t  ...           f              0.560456
# 1             f        f  ...           f              0.560456
# 2             f        t  ...           f              0.560456
# 3             f        f  ...           f              1.000000
# 4             f        t  ...           f              0.560456
# ...         ...      ...  ...         ...                   ...
# 6150          f        t  ...           f              0.000000
# 6151          f        f  ...           f              0.000000
# 6152          t        f  ...           t              0.000000
# 6154          f        f  ...           f              0.000000
# 6155          f        t  ...           f              0.000000
#
#      KGINCREASEDPREGNANCY STARTANTENATALCARRE  ART  PREVIOUSTERMPREGNANCIES  \
# 0                      14         1ºtrimester    f                        0
# 1                       5         1ºtrimester    f                        0
# 2                      12         1ºtrimester    f                        0
# 3                      12         1ºtrimester    f                        1
# 4                      11         1ºtrimester    t                        0
# ...                   ...                 ...  ...                      ...
# 6150                    0         1ºtrimester    f                        0
# 6151                    0         2ºtrimester    f                        0
# 6152                   13         1ºtrimester    f                        0
# 6154                    0         1ºtrimester    t                        0
# 6155                    3         1ºtrimester    t                        1
#
#      AMNIOTICLIQUID MISCARRIAGES  ANESTHESIA         TYPEOFBIRTH
# 0          stained+            0           t  emergencyc-section
# 1             clear            1           t       CESprogrammed
# 2             clear            1           t                 EUT
# 3          stained+            0           t                 EUT
# 4             clear            1           t                 EUT
# ...             ...          ...         ...                 ...
# 6150       stained+            0           t  emergencyc-section
# 6151       stained+            0           t  emergencyc-section
# 6152          clear            0           t                 EUT
# 6154          clear            2           t                 EUT
# 6155          clear            2           t  emergencyc-section
#
# [5261 rows x 23 columns]

# %%
le = preprocessing.LabelEncoder()

#hm_df.Publisher = hm_df.Publisher.astype(str)

for column in hm_df.columns:
    temp_new = le.fit_transform(hm_df[column].astype('category'))
    hm_df.drop(labels=[column], axis="columns", inplace=True)
    hm_df[column] = temp_new

X = hm_df.loc[:,'PREVIOUSCESAREAN':'ANESTHESIA']
Y = hm_df.loc[:,'TYPEOFBIRTH':]

# %%
sm = ADASYN(sampling_strategy='auto', random_state=None, n_neighbors=5, n_jobs=1)
X_adassin_1, Y_adassin_1 = sm.fit_resample(X, Y)
print(X_adassin_1.shape)
print(Y_adassin_1.shape)
# Out:
# (23785, 22)
# (23785, 1)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_adassin_1,Y_adassin_1,test_size=0.2,random_state=None)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19028 entries, 479 to 16749
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PREVIOUSCESAREAN            19028 non-null  int64
#  1   COMPLICATIONS               19028 non-null  int64
#  2   ROBSONGROUP                 19028 non-null  int64
#  3   ARTMODE                     19028 non-null  int64
#  4   PREVIOUSPRETERMPREGNANCIES  19028 non-null  int64
#  5   AMNIOCENTESIS               19028 non-null  int64
#  6   PREINDUCTION                19028 non-null  int64
#  7   INDUCTION                   19028 non-null  int64
#  8   EPISIOTOMY                  19028 non-null  int64
#  9   OXYTOCIN                    19028 non-null  int64
#  10  FetalINTRAPARTUMpH          19028 non-null  int64
#  11  PARITY                      19028 non-null  int64
#  12  OBSTETRICRISK               19028 non-null  int64
#  13  COMORBIDITY                 19028 non-null  int64
#  14  NUMBEROFPREVCESAREAN        19028 non-null  int64
#  15  KGINCREASEDPREGNANCY        19028 non-null  int64
#  16  STARTANTENATALCARRE         19028 non-null  int64
#  17  ART                         19028 non-null  int64
#  18  PREVIOUSTERMPREGNANCIES     19028 non-null  int64
#  19  AMNIOTICLIQUID              19028 non-null  int64
#  20  MISCARRIAGES                19028 non-null  int64
#  21  ANESTHESIA                  19028 non-null  int64
# dtypes: int64(22)
# memory usage: 3.3 MB

# %%
Y_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19028 entries, 479 to 16749
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TYPEOFBIRTH  19028 non-null  int64
# dtypes: int64(1)
# memory usage: 297.3 KB

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4757 entries, 21233 to 15672
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PREVIOUSCESAREAN            4757 non-null   int64
#  1   COMPLICATIONS               4757 non-null   int64
#  2   ROBSONGROUP                 4757 non-null   int64
#  3   ARTMODE                     4757 non-null   int64
#  4   PREVIOUSPRETERMPREGNANCIES  4757 non-null   int64
#  5   AMNIOCENTESIS               4757 non-null   int64
#  6   PREINDUCTION                4757 non-null   int64
#  7   INDUCTION                   4757 non-null   int64
#  8   EPISIOTOMY                  4757 non-null   int64
#  9   OXYTOCIN                    4757 non-null   int64
#  10  FetalINTRAPARTUMpH          4757 non-null   int64
#  11  PARITY                      4757 non-null   int64
#  12  OBSTETRICRISK               4757 non-null   int64
#  13  COMORBIDITY                 4757 non-null   int64
#  14  NUMBEROFPREVCESAREAN        4757 non-null   int64
#  15  KGINCREASEDPREGNANCY        4757 non-null   int64
#  16  STARTANTENATALCARRE         4757 non-null   int64
#  17  ART                         4757 non-null   int64
#  18  PREVIOUSTERMPREGNANCIES     4757 non-null   int64
#  19  AMNIOTICLIQUID              4757 non-null   int64
#  20  MISCARRIAGES                4757 non-null   int64
#  21  ANESTHESIA                  4757 non-null   int64
# dtypes: int64(22)
# memory usage: 854.8 KB

# %%
Y_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4757 entries, 21233 to 15672
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TYPEOFBIRTH  4757 non-null   int64
# dtypes: int64(1)
# memory usage: 74.3 KB

# %%
model = DecisionTreeClassifier(criterion = 'entropy')
model.fit(X_train,Y_train)
y_pred = model.predict(X_test)
print(accuracy_score(Y_test,y_pred))
print(precision_score(Y_test,y_pred,pos_label='positive',average='weighted'))
print(recall_score(Y_test,y_pred,pos_label='positive',average='micro'))

hm_dt_f1 = f1_score(Y_test, y_pred,average='micro')

print(hm_dt_f1)
# Out:
# 0.8484338869035106
# 0.8447147057642137
# 0.8484338869035106
# 0.8484338869035106
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,

# %%
RFC = RandomForestClassifier()
RFC.fit(X_train, Y_train.values.ravel())
y_pred = RFC.predict(X_test)
print(accuracy_score(Y_test,y_pred))
print(precision_score(Y_test,y_pred,pos_label='positive',average='weighted'))
print(recall_score(Y_test,y_pred,pos_label='positive',average='micro'))

hm_rfc_f1 = f1_score(Y_test, y_pred,average='micro')

print(hm_rfc_f1)
# Out:
# 0.8696657557284002
# 0.8682856746843394
# 0.8696657557284002
# 0.8696657557284002
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,

# %%
svc = SVC(gamma = 0.001, C = 1000)
y_pred = svc.fit(X_train, Y_train.values.ravel()).predict(X_test)
print(accuracy_score(Y_test,y_pred))
print(precision_score(Y_test,y_pred,pos_label='positive',average='weighted'))
print(recall_score(Y_test,y_pred,pos_label='positive',average='micro'))

hm_svc_f1 = f1_score(Y_test, y_pred,average='micro')

print(hm_svc_f1)
# Out:
# 0.7458482236703805
# 0.7446936274236562
# 0.7458482236703805
# 0.7458482236703805
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,

# %%
K = []
training = []
test = []
scores = {}
  
for k in range(2, 21):
    clf = KNeighborsClassifier(n_neighbors = k)
    clf.fit(X_train, Y_train.values.ravel())
  
    training_score = clf.score(X_train, Y_train)
    test_score = clf.score(X_test, Y_test)
    K.append(k)
  
    training.append(training_score)
    test.append(test_score)
    scores[k] = [training_score, test_score]
for keys, values in scores.items():
    print(keys, ':', values)
# Out:
# 2 : [0.8917384906453647, 0.8126970779903301]
# 3 : [0.8850641160395207, 0.8288837502627706]
# 4 : [0.8688774437670801, 0.8169014084507042]
# 5 : [0.8595753626235022, 0.8114357788522177]
# 6 : [0.8501156190876603, 0.8044986335926004]
# 7 : [0.8411814168593651, 0.7994534370401514]
# 8 : [0.8319844439772967, 0.7965104057178894]
# 9 : [0.8249947445869246, 0.7935673743956275]
# 10 : [0.8147992432205171, 0.781585032583561]
# 11 : [0.8080197603531638, 0.7769602690771494]
# 12 : [0.8005045196552449, 0.770023123817532]
# 13 : [0.7982446920327938, 0.764347277696027]
# 14 : [0.7926214000420433, 0.7607735968047088]
# 15 : [0.7881542989278957, 0.7574101324364095]
# 16 : [0.7829514399831827, 0.7536262350220727]
# 17 : [0.7764872819003573, 0.7414336766869876]
# 18 : [0.7712318688248896, 0.740382594071894]
# 19 : [0.7656611309648939, 0.7365986966575573]
# 20 : [0.7610363674584822, 0.7288206853058651]

# %%
model = KNeighborsClassifier(n_neighbors=2,weights='distance',p=1)
model.fit(X_train,Y_train.values.ravel())
y_pred = model.predict(X_test)
print(accuracy_score(Y_test,y_pred))
print(precision_score(Y_test,y_pred,pos_label='positive',average='weighted'))
print(recall_score(Y_test,y_pred,pos_label='positive',average='micro'))

hm_knn_f1 = f1_score(Y_test, y_pred,average='micro')

print(hm_knn_f1)
# Out:
# 0.8351902459533319
# 0.8307591388952044
# 0.8351902459533319
# 0.8351902459533319
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,

# %%
estimators = [('rf', RandomForestClassifier()),('svr', make_pipeline(StandardScaler(),LinearSVC())),('dt',DecisionTreeClassifier(criterion = 'entropy')),('knn',KNeighborsClassifier(n_neighbors=2,weights='distance',p=1))]
clf = StackingClassifier(estimators=estimators, final_estimator=LogisticRegression())
clf.fit(X_train, Y_train.values.ravel())
y_pred = clf.predict(X_test)
print(accuracy_score(Y_test,y_pred))
print(precision_score(Y_test,y_pred,pos_label='positive',average='weighted'))
print(recall_score(Y_test,y_pred,pos_label='positive',average='micro'))

hm_sc_f1 = f1_score(Y_test, y_pred,average='micro')

print(hm_sc_f1)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# 0.8774437670800925
# 0.8760360372938657
# 0.8774437670800925
# 0.8774437670800925
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,

# %%
hl_df = c_df[['PREVIOUSCESAREAN','COMPLICATIONS','ROBSONGROUP','ARTMODE','PREVIOUSPRETERMPREGNANCIES','AMNIOCENTESIS','PREINDUCTION','INDUCTION',
        'EPISIOTOMY','OXYTOCIN','FetalINTRAPARTUMpH',
        'GESTAGIONALAGE','HEIGHT','WEIGHT','BMI','AGE','CARDIOTOCOGRAPHY','MATERNALEDUCATION','SUBSTANCEABUSE','SMOKING','ALCOHOL','TYPEOFBIRTH']]

# %% [markdown]
# ### Checking duplicates

# %%
hl_df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6152    False
# 6153    False
# 6154    False
# 6155    False
# 6156    False
# Length: 6157, dtype: bool

# %%
hl_df.duplicated().sum()
# Out:
# 21

# %% [markdown]
# ### Drop duplicate records

# %%
hl_df = hl_df.drop_duplicates()
hl_df
# Out:
#      PREVIOUSCESAREAN COMPLICATIONS ROBSONGROUP ARTMODE  \
# 0                   f             f     group2a     NaN
# 1                   f             f      group6     NaN
# 2                   f             f      group1     NaN
# 3                   t             f      group5     NaN
# 4                   f             f      group1     FIV
# ...               ...           ...         ...     ...
# 6152                f             f      group8     NaN
# 6153                f             f      group3     NaN
# 6154                f             f      group1     IAD
# 6155                f             f     group2a     FIV
# 6156                f             f      group3     NaN
#
#       PREVIOUSPRETERMPREGNANCIES AMNIOCENTESIS PREINDUCTION INDUCTION  \
# 0                              0             f            t         t
# 1                              0             f            f         f
# 2                              0             f            f         f
# 3                              0             f            f         f
# 4                              0             f            f         f
# ...                          ...           ...          ...       ...
# 6152                           0             t            f         f
# 6153                           0             f            f         f
# 6154                           0             f            f         f
# 6155                           0             f            f         t
# 6156                           0             f            f         f
#
#      EPISIOTOMY OXYTOCIN  ... HEIGHT  WEIGHT    BMI  AGE  CARDIOTOCOGRAPHY  \
# 0           NaN        t  ...   1.58    70.0  28.04   30        continuous
# 1           NaN        f  ...   1.61    79.0  30.48   38        continuous
# 2             f        t  ...   1.56    72.0  29.59   25        continuous
# 3             f        f  ...   1.62    54.0  20.58   31        continuous
# 4             f        t  ...   1.47    51.0  23.60   28        continuous
# ...         ...      ...  ...    ...     ...    ...  ...               ...
# 6152          t        f  ...   1.56    49.0  20.00   35        continuous
# 6153          f        f  ...   1.64    59.0  21.51   29        continuous
# 6154          f        f  ...   1.59    64.0  20.00   39     discontinuous
# 6155          f        t  ...   1.48    50.0  23.28   41        continuous
# 6156          f        f  ...   1.65    75.2  24.00   32     discontinuous
#
#       MATERNALEDUCATION SUBSTANCEABUSE SMOKING ALCOHOL         TYPEOFBIRTH
# 0             secondary              f       f       f  emergencyc-section
# 1             secondary              f       f       f       CESprogrammed
# 2             secondary              f       f       f                 EUT
# 3             secondary              f       f       f                 EUT
# 4             secondary              f       f       f                 EUT
# ...                 ...            ...     ...     ...                 ...
# 6152          secondary              f       f       f                 EUT
# 6153          secondary              f       f       f                 EUT
# 6154          secondary              f       f       t                 EUT
# 6155            primary              f       f       f  emergencyc-section
# 6156        Sinestudios              f       f       f                 EUT
#
# [6136 rows x 22 columns]

# %%
hl_df = hl_df.replace(r'^\s*$', np.nan, regex=True)

# %% [markdown]
# ### Handling missing values of categorical attributes by mode

# %%
s = (hl_df.dtypes == 'object')
#print(s)
#print(s[s])
object_cols = list(s[s].index)
print("Categorical variables:")
print(object_cols)
print(len(object_cols))
# Out:
# Categorical variables:
# ['PREVIOUSCESAREAN', 'COMPLICATIONS', 'ROBSONGROUP', 'ARTMODE', 'AMNIOCENTESIS', 'PREINDUCTION', 'INDUCTION', 'EPISIOTOMY', 'OXYTOCIN', 'FetalINTRAPARTUMpH', 'CARDIOTOCOGRAPHY', 'MATERNALEDUCATION', 'SUBSTANCEABUSE', 'SMOKING', 'ALCOHOL', 'TYPEOFBIRTH']
# 16

# %%
for i in object_cols:
  x = hl_df[i].mode()[0]
  hl_df[i].fillna(x,inplace = True)
hl_df
# Out:
#      PREVIOUSCESAREAN COMPLICATIONS ROBSONGROUP ARTMODE  \
# 0                   f             f     group2a     FIV
# 1                   f             f      group6     FIV
# 2                   f             f      group1     FIV
# 3                   t             f      group5     FIV
# 4                   f             f      group1     FIV
# ...               ...           ...         ...     ...
# 6152                f             f      group8     FIV
# 6153                f             f      group3     FIV
# 6154                f             f      group1     IAD
# 6155                f             f     group2a     FIV
# 6156                f             f      group3     FIV
#
#       PREVIOUSPRETERMPREGNANCIES AMNIOCENTESIS PREINDUCTION INDUCTION  \
# 0                              0             f            t         t
# 1                              0             f            f         f
# 2                              0             f            f         f
# 3                              0             f            f         f
# 4                              0             f            f         f
# ...                          ...           ...          ...       ...
# 6152                           0             t            f         f
# 6153                           0             f            f         f
# 6154                           0             f            f         f
# 6155                           0             f            f         t
# 6156                           0             f            f         f
#
#      EPISIOTOMY OXYTOCIN  ... HEIGHT  WEIGHT    BMI  AGE  CARDIOTOCOGRAPHY  \
# 0             f        t  ...   1.58    70.0  28.04   30        continuous
# 1             f        f  ...   1.61    79.0  30.48   38        continuous
# 2             f        t  ...   1.56    72.0  29.59   25        continuous
# 3             f        f  ...   1.62    54.0  20.58   31        continuous
# 4             f        t  ...   1.47    51.0  23.60   28        continuous
# ...         ...      ...  ...    ...     ...    ...  ...               ...
# 6152          t        f  ...   1.56    49.0  20.00   35        continuous
# 6153          f        f  ...   1.64    59.0  21.51   29        continuous
# 6154          f        f  ...   1.59    64.0  20.00   39     discontinuous
# 6155          f        t  ...   1.48    50.0  23.28   41        continuous
# 6156          f        f  ...   1.65    75.2  24.00   32     discontinuous
#
#       MATERNALEDUCATION SUBSTANCEABUSE SMOKING ALCOHOL         TYPEOFBIRTH
# 0             secondary              f       f       f  emergencyc-section
# 1             secondary              f       f       f       CESprogrammed
# 2             secondary              f       f       f                 EUT
# 3             secondary              f       f       f                 EUT
# 4             secondary              f       f       f                 EUT
# ...                 ...            ...     ...     ...                 ...
# 6152          secondary              f       f       f                 EUT
# 6153          secondary              f       f       f                 EUT
# 6154          secondary              f       f       t                 EUT
# 6155            primary              f       f       f  emergencyc-section
# 6156        Sinestudios              f       f       f                 EUT
#
# [6136 rows x 22 columns]

# %% [markdown]
# ### Handling missing values of Numerical attributes using mean

# %%
s = (hl_df.dtypes != 'object')
number_cols = list(s[s].index)
print("Numerical variables:")
print(number_cols)
print(len(number_cols))
# Out:
# Numerical variables:
# ['PREVIOUSPRETERMPREGNANCIES', 'GESTAGIONALAGE', 'HEIGHT', 'WEIGHT', 'BMI', 'AGE']
# 6

# %%
for i in number_cols:
  x = hl_df[i].mean()
  hl_df[i].fillna(x,inplace = True)
hl_df
# Out:
#      PREVIOUSCESAREAN COMPLICATIONS ROBSONGROUP ARTMODE  \
# 0                   f             f     group2a     FIV
# 1                   f             f      group6     FIV
# 2                   f             f      group1     FIV
# 3                   t             f      group5     FIV
# 4                   f             f      group1     FIV
# ...               ...           ...         ...     ...
# 6152                f             f      group8     FIV
# 6153                f             f      group3     FIV
# 6154                f             f      group1     IAD
# 6155                f             f     group2a     FIV
# 6156                f             f      group3     FIV
#
#       PREVIOUSPRETERMPREGNANCIES AMNIOCENTESIS PREINDUCTION INDUCTION  \
# 0                              0             f            t         t
# 1                              0             f            f         f
# 2                              0             f            f         f
# 3                              0             f            f         f
# 4                              0             f            f         f
# ...                          ...           ...          ...       ...
# 6152                           0             t            f         f
# 6153                           0             f            f         f
# 6154                           0             f            f         f
# 6155                           0             f            f         t
# 6156                           0             f            f         f
#
#      EPISIOTOMY OXYTOCIN  ... HEIGHT  WEIGHT    BMI  AGE  CARDIOTOCOGRAPHY  \
# 0             f        t  ...   1.58    70.0  28.04   30        continuous
# 1             f        f  ...   1.61    79.0  30.48   38        continuous
# 2             f        t  ...   1.56    72.0  29.59   25        continuous
# 3             f        f  ...   1.62    54.0  20.58   31        continuous
# 4             f        t  ...   1.47    51.0  23.60   28        continuous
# ...         ...      ...  ...    ...     ...    ...  ...               ...
# 6152          t        f  ...   1.56    49.0  20.00   35        continuous
# 6153          f        f  ...   1.64    59.0  21.51   29        continuous
# 6154          f        f  ...   1.59    64.0  20.00   39     discontinuous
# 6155          f        t  ...   1.48    50.0  23.28   41        continuous
# 6156          f        f  ...   1.65    75.2  24.00   32     discontinuous
#
#       MATERNALEDUCATION SUBSTANCEABUSE SMOKING ALCOHOL         TYPEOFBIRTH
# 0             secondary              f       f       f  emergencyc-section
# 1             secondary              f       f       f       CESprogrammed
# 2             secondary              f       f       f                 EUT
# 3             secondary              f       f       f                 EUT
# 4             secondary              f       f       f                 EUT
# ...                 ...            ...     ...     ...                 ...
# 6152          secondary              f       f       f                 EUT
# 6153          secondary              f       f       f                 EUT
# 6154          secondary              f       f       t                 EUT
# 6155            primary              f       f       f  emergencyc-section
# 6156        Sinestudios              f       f       f                 EUT
#
# [6136 rows x 22 columns]

# %%
hl_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6136 entries, 0 to 6156
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PREVIOUSCESAREAN            6136 non-null   object
#  1   COMPLICATIONS               6136 non-null   object
#  2   ROBSONGROUP                 6136 non-null   object
#  3   ARTMODE                     6136 non-null   object
#  4   PREVIOUSPRETERMPREGNANCIES  6136 non-null   int64
#  5   AMNIOCENTESIS               6136 non-null   object
#  6   PREINDUCTION                6136 non-null   object
#  7   INDUCTION                   6136 non-null   object
#  8   EPISIOTOMY                  6136 non-null   object
#  9   OXYTOCIN                    6136 non-null   object
#  10  FetalINTRAPARTUMpH          6136 non-null   object
#  11  GESTAGIONALAGE              6136 non-null   int64
#  12  HEIGHT                      6136 non-null   float64
#  13  WEIGHT                      6136 non-null   float64
#  14  BMI                         6136 non-null   float64
#  15  AGE                         6136 non-null   int64
#  16  CARDIOTOCOGRAPHY            6136 non-null   object
#  17  MATERNALEDUCATION           6136 non-null   object
#  18  SUBSTANCEABUSE              6136 non-null   object
#  19  SMOKING                     6136 non-null   object
#  20  ALCOHOL                     6136 non-null   object
#  21  TYPEOFBIRTH                 6136 non-null   object
# dtypes: float64(3), int64(3), object(16)
# memory usage: 1.1+ MB

# %% [markdown]
# ### Checking NULL values

# %%
hl_df.isnull().sum()
# Out:
# PREVIOUSCESAREAN              0
# COMPLICATIONS                 0
# ROBSONGROUP                   0
# ARTMODE                       0
# PREVIOUSPRETERMPREGNANCIES    0
# AMNIOCENTESIS                 0
# PREINDUCTION                  0
# INDUCTION                     0
# EPISIOTOMY                    0
# OXYTOCIN                      0
# FetalINTRAPARTUMpH            0
# GESTAGIONALAGE                0
# HEIGHT                        0
# WEIGHT                        0
# BMI                           0
# AGE                           0
# CARDIOTOCOGRAPHY              0
# MATERNALEDUCATION             0
# SUBSTANCEABUSE                0
# SMOKING                       0
# ALCOHOL                       0
# TYPEOFBIRTH                   0
# dtype: int64

# %%
hl_df.TYPEOFBIRTH.unique()
# Out:
# array(['emergencyc-section', 'CESprogrammed', 'EUT', 'vacum', 'FORC',
#        'ESP', 'NALGASVAGINAL'], dtype=object)

# %%
a = hl_df['TYPEOFBIRTH'].values.tolist()
s = set(a)
for x in s:
  print(x,":",a.count(x))
# Out:
# EUT : 4220
# emergencyc-section : 687
# CESprogrammed : 325
# FORC : 87
# ESP : 44
# NALGASVAGINAL : 8
# vacum : 765

# %%
hl_df
# Out:
#      PREVIOUSCESAREAN COMPLICATIONS ROBSONGROUP ARTMODE  \
# 0                   f             f     group2a     FIV
# 1                   f             f      group6     FIV
# 2                   f             f      group1     FIV
# 3                   t             f      group5     FIV
# 4                   f             f      group1     FIV
# ...               ...           ...         ...     ...
# 6152                f             f      group8     FIV
# 6153                f             f      group3     FIV
# 6154                f             f      group1     IAD
# 6155                f             f     group2a     FIV
# 6156                f             f      group3     FIV
#
#       PREVIOUSPRETERMPREGNANCIES AMNIOCENTESIS PREINDUCTION INDUCTION  \
# 0                              0             f            t         t
# 1                              0             f            f         f
# 2                              0             f            f         f
# 3                              0             f            f         f
# 4                              0             f            f         f
# ...                          ...           ...          ...       ...
# 6152                           0             t            f         f
# 6153                           0             f            f         f
# 6154                           0             f            f         f
# 6155                           0             f            f         t
# 6156                           0             f            f         f
#
#      EPISIOTOMY OXYTOCIN  ... HEIGHT  WEIGHT    BMI  AGE  CARDIOTOCOGRAPHY  \
# 0             f        t  ...   1.58    70.0  28.04   30        continuous
# 1             f        f  ...   1.61    79.0  30.48   38        continuous
# 2             f        t  ...   1.56    72.0  29.59   25        continuous
# 3             f        f  ...   1.62    54.0  20.58   31        continuous
# 4             f        t  ...   1.47    51.0  23.60   28        continuous
# ...         ...      ...  ...    ...     ...    ...  ...               ...
# 6152          t        f  ...   1.56    49.0  20.00   35        continuous
# 6153          f        f  ...   1.64    59.0  21.51   29        continuous
# 6154          f        f  ...   1.59    64.0  20.00   39     discontinuous
# 6155          f        t  ...   1.48    50.0  23.28   41        continuous
# 6156          f        f  ...   1.65    75.2  24.00   32     discontinuous
#
#       MATERNALEDUCATION SUBSTANCEABUSE SMOKING ALCOHOL         TYPEOFBIRTH
# 0             secondary              f       f       f  emergencyc-section
# 1             secondary              f       f       f       CESprogrammed
# 2             secondary              f       f       f                 EUT
# 3             secondary              f       f       f                 EUT
# 4             secondary              f       f       f                 EUT
# ...                 ...            ...     ...     ...                 ...
# 6152          secondary              f       f       f                 EUT
# 6153          secondary              f       f       f                 EUT
# 6154          secondary              f       f       t                 EUT
# 6155            primary              f       f       f  emergencyc-section
# 6156        Sinestudios              f       f       f                 EUT
#
# [6136 rows x 22 columns]

# %%
le = preprocessing.LabelEncoder()

#hl_df.Publisher = hl_df.Publisher.astype(str)

for column in hl_df.columns:
    temp_new = le.fit_transform(hl_df[column].astype('category'))
    hl_df.drop(labels=[column], axis="columns", inplace=True)
    hl_df[column] = temp_new

X = hl_df.loc[:,'PREVIOUSCESAREAN':'ALCOHOL']
Y = hl_df.loc[:,'TYPEOFBIRTH':]

# %%
sm = ADASYN(sampling_strategy='auto', random_state=None, n_neighbors=5, n_jobs=1)
X_adassin_1, Y_adassin_1 = sm.fit_resample(X, Y)
print(X_adassin_1.shape)
print(Y_adassin_1.shape)
# Out:
# (29610, 21)
# (29610, 1)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_adassin_1,Y_adassin_1,test_size=0.2,random_state=None)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23688 entries, 24814 to 13263
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PREVIOUSCESAREAN            23688 non-null  int64
#  1   COMPLICATIONS               23688 non-null  int64
#  2   ROBSONGROUP                 23688 non-null  int64
#  3   ARTMODE                     23688 non-null  int64
#  4   PREVIOUSPRETERMPREGNANCIES  23688 non-null  int64
#  5   AMNIOCENTESIS               23688 non-null  int64
#  6   PREINDUCTION                23688 non-null  int64
#  7   INDUCTION                   23688 non-null  int64
#  8   EPISIOTOMY                  23688 non-null  int64
#  9   OXYTOCIN                    23688 non-null  int64
#  10  FetalINTRAPARTUMpH          23688 non-null  int64
#  11  GESTAGIONALAGE              23688 non-null  int64
#  12  HEIGHT                      23688 non-null  int64
#  13  WEIGHT                      23688 non-null  int64
#  14  BMI                         23688 non-null  int64
#  15  AGE                         23688 non-null  int64
#  16  CARDIOTOCOGRAPHY            23688 non-null  int64
#  17  MATERNALEDUCATION           23688 non-null  int64
#  18  SUBSTANCEABUSE              23688 non-null  int64
#  19  SMOKING                     23688 non-null  int64
#  20  ALCOHOL                     23688 non-null  int64
# dtypes: int64(21)
# memory usage: 4.0 MB

# %%
Y_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23688 entries, 24814 to 13263
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TYPEOFBIRTH  23688 non-null  int64
# dtypes: int64(1)
# memory usage: 370.1 KB

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5922 entries, 14081 to 17093
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PREVIOUSCESAREAN            5922 non-null   int64
#  1   COMPLICATIONS               5922 non-null   int64
#  2   ROBSONGROUP                 5922 non-null   int64
#  3   ARTMODE                     5922 non-null   int64
#  4   PREVIOUSPRETERMPREGNANCIES  5922 non-null   int64
#  5   AMNIOCENTESIS               5922 non-null   int64
#  6   PREINDUCTION                5922 non-null   int64
#  7   INDUCTION                   5922 non-null   int64
#  8   EPISIOTOMY                  5922 non-null   int64
#  9   OXYTOCIN                    5922 non-null   int64
#  10  FetalINTRAPARTUMpH          5922 non-null   int64
#  11  GESTAGIONALAGE              5922 non-null   int64
#  12  HEIGHT                      5922 non-null   int64
#  13  WEIGHT                      5922 non-null   int64
#  14  BMI                         5922 non-null   int64
#  15  AGE                         5922 non-null   int64
#  16  CARDIOTOCOGRAPHY            5922 non-null   int64
#  17  MATERNALEDUCATION           5922 non-null   int64
#  18  SUBSTANCEABUSE              5922 non-null   int64
#  19  SMOKING                     5922 non-null   int64
#  20  ALCOHOL                     5922 non-null   int64
# dtypes: int64(21)
# memory usage: 1017.8 KB

# %%
Y_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5922 entries, 14081 to 17093
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TYPEOFBIRTH  5922 non-null   int64
# dtypes: int64(1)
# memory usage: 92.5 KB

# %%
model = DecisionTreeClassifier(criterion = 'entropy')
model.fit(X_train,Y_train)
y_pred = model.predict(X_test)
print(accuracy_score(Y_test,y_pred))
print(precision_score(Y_test,y_pred,pos_label='positive',average='weighted'))
print(recall_score(Y_test,y_pred,pos_label='positive',average='micro'))

hl_dt_f1 = f1_score(Y_test, y_pred,average='micro')

print(hl_dt_f1)
# Out:
# 0.856467409658899
# 0.8531106880387458
# 0.856467409658899
# 0.856467409658899
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,

# %%
RFC = RandomForestClassifier()
RFC.fit(X_train, Y_train.values.ravel())
y_pred = RFC.predict(X_test)
print(accuracy_score(Y_test,y_pred))
print(precision_score(Y_test,y_pred,pos_label='positive',average='weighted'))
print(recall_score(Y_test,y_pred,pos_label='positive',average='micro'))

hl_rfc_f1 = f1_score(Y_test, y_pred,average='micro')

print(hl_rfc_f1)
# Out:
# 0.9157379263762242
# 0.9151496942716718
# 0.9157379263762242
# 0.9157379263762242
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,

# %%
svc = SVC(gamma = 0.001, C = 1000)
y_pred = svc.fit(X_train, Y_train.values.ravel()).predict(X_test)
print(accuracy_score(Y_test,y_pred))
print(precision_score(Y_test,y_pred,pos_label='positive',average='weighted'))
print(recall_score(Y_test,y_pred,pos_label='positive',average='micro'))

hl_svc_f1 = f1_score(Y_test, y_pred,average='micro')

print(hl_svc_f1)
# Out:
# 0.9159067882472138
# 0.9127383648492797
# 0.9159067882472138
# 0.9159067882472138
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,

# %%
K = []
training = []
test = []
scores = {}
  
for k in range(2, 21):
    clf = KNeighborsClassifier(n_neighbors = k)
    clf.fit(X_train, Y_train.values.ravel())
  
    training_score = clf.score(X_train, Y_train)
    test_score = clf.score(X_test, Y_test)
    K.append(k)
  
    training.append(training_score)
    test.append(test_score)
    scores[k] = [training_score, test_score]
for keys, values in scores.items():
    print(keys, ':', values)
# Out:
# 2 : [0.9375633232016211, 0.8056399864910503]
# 3 : [0.9023134076325565, 0.7965214454576157]
# 4 : [0.8710739614994935, 0.7725430597771024]
# 5 : [0.8509793988517392, 0.7563323201621074]
# 6 : [0.8307159743329956, 0.7440054035798717]
# 7 : [0.8137875717662951, 0.7375886524822695]
# 8 : [0.7949172576832151, 0.7196892941573793]
# 9 : [0.7814083080040527, 0.7105707531239446]
# 10 : [0.7682370820668692, 0.6985815602836879]
# 11 : [0.7548969942586964, 0.6887875717662951]
# 12 : [0.7416413373860182, 0.6764606551840594]
# 13 : [0.7315096251266464, 0.6668355285376562]
# 14 : [0.7198581560283688, 0.6573792637622425]
# 15 : [0.7096420128335021, 0.6523134076325565]
# 16 : [0.7031830462681526, 0.6465721040189125]
# 17 : [0.6961330631543398, 0.6391421816953732]
# 18 : [0.6891252955082743, 0.6355960824045931]
# 19 : [0.6812732185072611, 0.6303613644039175]
# 20 : [0.6742232353934482, 0.6261398176291794]

# %%
model = KNeighborsClassifier(n_neighbors=2,weights='distance',p=1)
model.fit(X_train,Y_train.values.ravel())
y_pred = model.predict(X_test)
print(accuracy_score(Y_test,y_pred))
print(precision_score(Y_test,y_pred,pos_label='positive',average='weighted'))
print(recall_score(Y_test,y_pred,pos_label='positive',average='micro'))

hl_knn_f1 = f1_score(Y_test, y_pred,average='micro')

print(hl_knn_f1)
# Out:
# 0.8807835190813914
# 0.8767274788131837
# 0.8807835190813914
# 0.8807835190813914
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,

# %%
estimators = [('rf', RandomForestClassifier()),('svr', make_pipeline(StandardScaler(),LinearSVC())),('dt',DecisionTreeClassifier(criterion = 'entropy')),('knn',KNeighborsClassifier(n_neighbors=2,weights='distance',p=1))]
clf = StackingClassifier(estimators=estimators, final_estimator=LogisticRegression())
clf.fit(X_train, Y_train.values.ravel())
y_pred = clf.predict(X_test)
print(accuracy_score(Y_test,y_pred))
print(precision_score(Y_test,y_pred,pos_label='positive',average='weighted'))
print(recall_score(Y_test,y_pred,pos_label='positive',average='micro'))

hl_sc_f1 = f1_score(Y_test, y_pred,average='micro')

print(hl_sc_f1)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# 0.9436001350894968
# 0.9435688505431163
# 0.9436001350894968
# 0.9436001350894968
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,

# %%
ml_df = c_df[['PARITY','OBSTETRICRISK','COMORBIDITY','NUMBEROFPREVCESAREAN','KGINCREASEDPREGNANCY','STARTANTENATALCARRE',
        'ART','PREVIOUSTERMPREGNANCIES','AMNIOTICLIQUID','MISCARRIAGES','ANESTHESIA',
        'GESTAGIONALAGE','HEIGHT','WEIGHT','BMI','AGE','CARDIOTOCOGRAPHY','MATERNALEDUCATION','SUBSTANCEABUSE','SMOKING','ALCOHOL','TYPEOFBIRTH']]

# %% [markdown]
# ### Checking duplicates

# %%
ml_df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6152    False
# 6153    False
# 6154    False
# 6155    False
# 6156    False
# Length: 6157, dtype: bool

# %%
ml_df.duplicated().sum()
# Out:
# 20

# %% [markdown]
# ### Drop duplicate records

# %%
ml_df = ml_df.drop_duplicates()
ml_df
# Out:
#       PARITY OBSTETRICRISK COMORBIDITY  NUMBEROFPREVCESAREAN  \
# 0          0             t           f                   NaN
# 1         10             f           f                   NaN
# 2         10             f           f                   NaN
# 3       1001             t           f                   1.0
# 4         10             f           f                   NaN
# ...      ...           ...         ...                   ...
# 6152       0             t           t                   0.0
# 6153    1001             f           f                   0.0
# 6154      20             f           f                   0.0
# 6155    1020             t           f                   0.0
# 6156    2002             f           f                   0.0
#
#       KGINCREASEDPREGNANCY STARTANTENATALCARRE ART  PREVIOUSTERMPREGNANCIES  \
# 0                       14         1ºtrimester   f                        0
# 1                        5         1ºtrimester   f                        0
# 2                       12         1ºtrimester   f                        0
# 3                       12         1ºtrimester   f                        1
# 4                       11         1ºtrimester   t                        0
# ...                    ...                 ...  ..                      ...
# 6152                    13         1ºtrimester   f                        0
# 6153                     0         1ºtrimester   f                        1
# 6154                     0         1ºtrimester   t                        0
# 6155                     3         1ºtrimester   t                        1
# 6156                     0         1ºtrimester   f                        2
#
#      AMNIOTICLIQUID  MISCARRIAGES  ... HEIGHT  WEIGHT    BMI  AGE  \
# 0          stained+             0  ...   1.58    70.0  28.04   30
# 1             clear             1  ...   1.61    79.0  30.48   38
# 2             clear             1  ...   1.56    72.0  29.59   25
# 3          stained+             0  ...   1.62    54.0  20.58   31
# 4             clear             1  ...   1.47    51.0  23.60   28
# ...             ...           ...  ...    ...     ...    ...  ...
# 6152          clear             0  ...   1.56    49.0  20.00   35
# 6153          clear             0  ...   1.64    59.0  21.51   29
# 6154          clear             2  ...   1.59    64.0  20.00   39
# 6155          clear             2  ...   1.48    50.0  23.28   41
# 6156          clear             0  ...   1.65    75.2  24.00   32
#
#       CARDIOTOCOGRAPHY  MATERNALEDUCATION SUBSTANCEABUSE SMOKING ALCOHOL  \
# 0           continuous          secondary              f       f       f
# 1           continuous          secondary              f       f       f
# 2           continuous          secondary              f       f       f
# 3           continuous          secondary              f       f       f
# 4           continuous          secondary              f       f       f
# ...                ...                ...            ...     ...     ...
# 6152        continuous          secondary              f       f       f
# 6153        continuous          secondary              f       f       f
# 6154     discontinuous          secondary              f       f       t
# 6155        continuous            primary              f       f       f
# 6156     discontinuous        Sinestudios              f       f       f
#
#              TYPEOFBIRTH
# 0     emergencyc-section
# 1          CESprogrammed
# 2                    EUT
# 3                    EUT
# 4                    EUT
# ...                  ...
# 6152                 EUT
# 6153                 EUT
# 6154                 EUT
# 6155  emergencyc-section
# 6156                 EUT
#
# [6137 rows x 22 columns]

# %%
ml_df = ml_df.replace(r'^\s*$', np.nan, regex=True)

# %% [markdown]
# ### Handling missing values of categorical attributes by mode

# %%
s = (ml_df.dtypes == 'object')
#print(s)
#print(s[s])
object_cols = list(s[s].index)
print("Categorical variables:")
print(object_cols)
print(len(object_cols))
# Out:
# Categorical variables:
# ['OBSTETRICRISK', 'COMORBIDITY', 'STARTANTENATALCARRE', 'ART', 'AMNIOTICLIQUID', 'ANESTHESIA', 'CARDIOTOCOGRAPHY', 'MATERNALEDUCATION', 'SUBSTANCEABUSE', 'SMOKING', 'ALCOHOL', 'TYPEOFBIRTH']
# 12

# %%
for i in object_cols:
  x = ml_df[i].mode()[0]
  ml_df[i].fillna(x,inplace = True)
ml_df
# Out:
#       PARITY OBSTETRICRISK COMORBIDITY  NUMBEROFPREVCESAREAN  \
# 0          0             t           f                   NaN
# 1         10             f           f                   NaN
# 2         10             f           f                   NaN
# 3       1001             t           f                   1.0
# 4         10             f           f                   NaN
# ...      ...           ...         ...                   ...
# 6152       0             t           t                   0.0
# 6153    1001             f           f                   0.0
# 6154      20             f           f                   0.0
# 6155    1020             t           f                   0.0
# 6156    2002             f           f                   0.0
#
#       KGINCREASEDPREGNANCY STARTANTENATALCARRE ART  PREVIOUSTERMPREGNANCIES  \
# 0                       14         1ºtrimester   f                        0
# 1                        5         1ºtrimester   f                        0
# 2                       12         1ºtrimester   f                        0
# 3                       12         1ºtrimester   f                        1
# 4                       11         1ºtrimester   t                        0
# ...                    ...                 ...  ..                      ...
# 6152                    13         1ºtrimester   f                        0
# 6153                     0         1ºtrimester   f                        1
# 6154                     0         1ºtrimester   t                        0
# 6155                     3         1ºtrimester   t                        1
# 6156                     0         1ºtrimester   f                        2
#
#      AMNIOTICLIQUID  MISCARRIAGES  ... HEIGHT  WEIGHT    BMI  AGE  \
# 0          stained+             0  ...   1.58    70.0  28.04   30
# 1             clear             1  ...   1.61    79.0  30.48   38
# 2             clear             1  ...   1.56    72.0  29.59   25
# 3          stained+             0  ...   1.62    54.0  20.58   31
# 4             clear             1  ...   1.47    51.0  23.60   28
# ...             ...           ...  ...    ...     ...    ...  ...
# 6152          clear             0  ...   1.56    49.0  20.00   35
# 6153          clear             0  ...   1.64    59.0  21.51   29
# 6154          clear             2  ...   1.59    64.0  20.00   39
# 6155          clear             2  ...   1.48    50.0  23.28   41
# 6156          clear             0  ...   1.65    75.2  24.00   32
#
#       CARDIOTOCOGRAPHY  MATERNALEDUCATION SUBSTANCEABUSE SMOKING ALCOHOL  \
# 0           continuous          secondary              f       f       f
# 1           continuous          secondary              f       f       f
# 2           continuous          secondary              f       f       f
# 3           continuous          secondary              f       f       f
# 4           continuous          secondary              f       f       f
# ...                ...                ...            ...     ...     ...
# 6152        continuous          secondary              f       f       f
# 6153        continuous          secondary              f       f       f
# 6154     discontinuous          secondary              f       f       t
# 6155        continuous            primary              f       f       f
# 6156     discontinuous        Sinestudios              f       f       f
#
#              TYPEOFBIRTH
# 0     emergencyc-section
# 1          CESprogrammed
# 2                    EUT
# 3                    EUT
# 4                    EUT
# ...                  ...
# 6152                 EUT
# 6153                 EUT
# 6154                 EUT
# 6155  emergencyc-section
# 6156                 EUT
#
# [6137 rows x 22 columns]

# %% [markdown]
# ### Handling missing values of Numerical attributes using mean

# %%
s = (ml_df.dtypes != 'object')
number_cols = list(s[s].index)
print("Numerical variables:")
print(number_cols)
print(len(number_cols))
# Out:
# Numerical variables:
# ['PARITY', 'NUMBEROFPREVCESAREAN', 'KGINCREASEDPREGNANCY', 'PREVIOUSTERMPREGNANCIES', 'MISCARRIAGES', 'GESTAGIONALAGE', 'HEIGHT', 'WEIGHT', 'BMI', 'AGE']
# 10

# %%
for i in number_cols:
  x = ml_df[i].mean()
  ml_df[i].fillna(x,inplace = True)
ml_df
# Out:
#       PARITY OBSTETRICRISK COMORBIDITY  NUMBEROFPREVCESAREAN  \
# 0          0             t           f              0.514344
# 1         10             f           f              0.514344
# 2         10             f           f              0.514344
# 3       1001             t           f              1.000000
# 4         10             f           f              0.514344
# ...      ...           ...         ...                   ...
# 6152       0             t           t              0.000000
# 6153    1001             f           f              0.000000
# 6154      20             f           f              0.000000
# 6155    1020             t           f              0.000000
# 6156    2002             f           f              0.000000
#
#       KGINCREASEDPREGNANCY STARTANTENATALCARRE ART  PREVIOUSTERMPREGNANCIES  \
# 0                       14         1ºtrimester   f                        0
# 1                        5         1ºtrimester   f                        0
# 2                       12         1ºtrimester   f                        0
# 3                       12         1ºtrimester   f                        1
# 4                       11         1ºtrimester   t                        0
# ...                    ...                 ...  ..                      ...
# 6152                    13         1ºtrimester   f                        0
# 6153                     0         1ºtrimester   f                        1
# 6154                     0         1ºtrimester   t                        0
# 6155                     3         1ºtrimester   t                        1
# 6156                     0         1ºtrimester   f                        2
#
#      AMNIOTICLIQUID  MISCARRIAGES  ... HEIGHT  WEIGHT    BMI  AGE  \
# 0          stained+             0  ...   1.58    70.0  28.04   30
# 1             clear             1  ...   1.61    79.0  30.48   38
# 2             clear             1  ...   1.56    72.0  29.59   25
# 3          stained+             0  ...   1.62    54.0  20.58   31
# 4             clear             1  ...   1.47    51.0  23.60   28
# ...             ...           ...  ...    ...     ...    ...  ...
# 6152          clear             0  ...   1.56    49.0  20.00   35
# 6153          clear             0  ...   1.64    59.0  21.51   29
# 6154          clear             2  ...   1.59    64.0  20.00   39
# 6155          clear             2  ...   1.48    50.0  23.28   41
# 6156          clear             0  ...   1.65    75.2  24.00   32
#
#       CARDIOTOCOGRAPHY  MATERNALEDUCATION SUBSTANCEABUSE SMOKING ALCOHOL  \
# 0           continuous          secondary              f       f       f
# 1           continuous          secondary              f       f       f
# 2           continuous          secondary              f       f       f
# 3           continuous          secondary              f       f       f
# 4           continuous          secondary              f       f       f
# ...                ...                ...            ...     ...     ...
# 6152        continuous          secondary              f       f       f
# 6153        continuous          secondary              f       f       f
# 6154     discontinuous          secondary              f       f       t
# 6155        continuous            primary              f       f       f
# 6156     discontinuous        Sinestudios              f       f       f
#
#              TYPEOFBIRTH
# 0     emergencyc-section
# 1          CESprogrammed
# 2                    EUT
# 3                    EUT
# 4                    EUT
# ...                  ...
# 6152                 EUT
# 6153                 EUT
# 6154                 EUT
# 6155  emergencyc-section
# 6156                 EUT
#
# [6137 rows x 22 columns]

# %%
ml_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6137 entries, 0 to 6156
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PARITY                   6137 non-null   int64
#  1   OBSTETRICRISK            6137 non-null   object
#  2   COMORBIDITY              6137 non-null   object
#  3   NUMBEROFPREVCESAREAN     6137 non-null   float64
#  4   KGINCREASEDPREGNANCY     6137 non-null   int64
#  5   STARTANTENATALCARRE      6137 non-null   object
#  6   ART                      6137 non-null   object
#  7   PREVIOUSTERMPREGNANCIES  6137 non-null   int64
#  8   AMNIOTICLIQUID           6137 non-null   object
#  9   MISCARRIAGES             6137 non-null   int64
#  10  ANESTHESIA               6137 non-null   object
#  11  GESTAGIONALAGE           6137 non-null   int64
#  12  HEIGHT                   6137 non-null   float64
#  13  WEIGHT                   6137 non-null   float64
#  14  BMI                      6137 non-null   float64
#  15  AGE                      6137 non-null   int64
#  16  CARDIOTOCOGRAPHY         6137 non-null   object
#  17  MATERNALEDUCATION        6137 non-null   object
#  18  SUBSTANCEABUSE           6137 non-null   object
#  19  SMOKING                  6137 non-null   object
#  20  ALCOHOL                  6137 non-null   object
#  21  TYPEOFBIRTH              6137 non-null   object
# dtypes: float64(4), int64(6), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# ### Checking NULL values

# %%
ml_df.isnull().sum()
# Out:
# PARITY                     0
# OBSTETRICRISK              0
# COMORBIDITY                0
# NUMBEROFPREVCESAREAN       0
# KGINCREASEDPREGNANCY       0
# STARTANTENATALCARRE        0
# ART                        0
# PREVIOUSTERMPREGNANCIES    0
# AMNIOTICLIQUID             0
# MISCARRIAGES               0
# ANESTHESIA                 0
# GESTAGIONALAGE             0
# HEIGHT                     0
# WEIGHT                     0
# BMI                        0
# AGE                        0
# CARDIOTOCOGRAPHY           0
# MATERNALEDUCATION          0
# SUBSTANCEABUSE             0
# SMOKING                    0
# ALCOHOL                    0
# TYPEOFBIRTH                0
# dtype: int64

# %%
ml_df.TYPEOFBIRTH.unique()
# Out:
# array(['emergencyc-section', 'CESprogrammed', 'EUT', 'vacum', 'FORC',
#        'ESP', 'NALGASVAGINAL'], dtype=object)

# %%
a = ml_df['TYPEOFBIRTH'].values.tolist()
s = set(a)
for x in s:
  print(x,":",a.count(x))
# Out:
# EUT : 4219
# emergencyc-section : 689
# CESprogrammed : 325
# FORC : 87
# ESP : 44
# NALGASVAGINAL : 8
# vacum : 765

# %%
ml_df
# Out:
#       PARITY OBSTETRICRISK COMORBIDITY  NUMBEROFPREVCESAREAN  \
# 0          0             t           f              0.514344
# 1         10             f           f              0.514344
# 2         10             f           f              0.514344
# 3       1001             t           f              1.000000
# 4         10             f           f              0.514344
# ...      ...           ...         ...                   ...
# 6152       0             t           t              0.000000
# 6153    1001             f           f              0.000000
# 6154      20             f           f              0.000000
# 6155    1020             t           f              0.000000
# 6156    2002             f           f              0.000000
#
#       KGINCREASEDPREGNANCY STARTANTENATALCARRE ART  PREVIOUSTERMPREGNANCIES  \
# 0                       14         1ºtrimester   f                        0
# 1                        5         1ºtrimester   f                        0
# 2                       12         1ºtrimester   f                        0
# 3                       12         1ºtrimester   f                        1
# 4                       11         1ºtrimester   t                        0
# ...                    ...                 ...  ..                      ...
# 6152                    13         1ºtrimester   f                        0
# 6153                     0         1ºtrimester   f                        1
# 6154                     0         1ºtrimester   t                        0
# 6155                     3         1ºtrimester   t                        1
# 6156                     0         1ºtrimester   f                        2
#
#      AMNIOTICLIQUID  MISCARRIAGES  ... HEIGHT  WEIGHT    BMI  AGE  \
# 0          stained+             0  ...   1.58    70.0  28.04   30
# 1             clear             1  ...   1.61    79.0  30.48   38
# 2             clear             1  ...   1.56    72.0  29.59   25
# 3          stained+             0  ...   1.62    54.0  20.58   31
# 4             clear             1  ...   1.47    51.0  23.60   28
# ...             ...           ...  ...    ...     ...    ...  ...
# 6152          clear             0  ...   1.56    49.0  20.00   35
# 6153          clear             0  ...   1.64    59.0  21.51   29
# 6154          clear             2  ...   1.59    64.0  20.00   39
# 6155          clear             2  ...   1.48    50.0  23.28   41
# 6156          clear             0  ...   1.65    75.2  24.00   32
#
#       CARDIOTOCOGRAPHY  MATERNALEDUCATION SUBSTANCEABUSE SMOKING ALCOHOL  \
# 0           continuous          secondary              f       f       f
# 1           continuous          secondary              f       f       f
# 2           continuous          secondary              f       f       f
# 3           continuous          secondary              f       f       f
# 4           continuous          secondary              f       f       f
# ...                ...                ...            ...     ...     ...
# 6152        continuous          secondary              f       f       f
# 6153        continuous          secondary              f       f       f
# 6154     discontinuous          secondary              f       f       t
# 6155        continuous            primary              f       f       f
# 6156     discontinuous        Sinestudios              f       f       f
#
#              TYPEOFBIRTH
# 0     emergencyc-section
# 1          CESprogrammed
# 2                    EUT
# 3                    EUT
# 4                    EUT
# ...                  ...
# 6152                 EUT
# 6153                 EUT
# 6154                 EUT
# 6155  emergencyc-section
# 6156                 EUT
#
# [6137 rows x 22 columns]

# %%
le = preprocessing.LabelEncoder()

#ml_df.Publisher = ml_df.Publisher.astype(str)

for column in ml_df.columns:
    temp_new = le.fit_transform(ml_df[column].astype('category'))
    ml_df.drop(labels=[column], axis="columns", inplace=True)
    ml_df[column] = temp_new

X = ml_df.loc[:,'PARITY':'ALCOHOL']
Y = ml_df.loc[:,'TYPEOFBIRTH':]

# %%
sm = ADASYN(sampling_strategy='auto', random_state=None, n_neighbors=5, n_jobs=1)
X_adassin_1, Y_adassin_1 = sm.fit_resample(X, Y)
print(X_adassin_1.shape)
print(Y_adassin_1.shape)
# Out:
# (29493, 21)
# (29493, 1)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_adassin_1,Y_adassin_1,test_size=0.2,random_state=None)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23594 entries, 4241 to 16578
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PARITY                   23594 non-null  int64
#  1   OBSTETRICRISK            23594 non-null  int64
#  2   COMORBIDITY              23594 non-null  int64
#  3   NUMBEROFPREVCESAREAN     23594 non-null  int64
#  4   KGINCREASEDPREGNANCY     23594 non-null  int64
#  5   STARTANTENATALCARRE      23594 non-null  int64
#  6   ART                      23594 non-null  int64
#  7   PREVIOUSTERMPREGNANCIES  23594 non-null  int64
#  8   AMNIOTICLIQUID           23594 non-null  int64
#  9   MISCARRIAGES             23594 non-null  int64
#  10  ANESTHESIA               23594 non-null  int64
#  11  GESTAGIONALAGE           23594 non-null  int64
#  12  HEIGHT                   23594 non-null  int64
#  13  WEIGHT                   23594 non-null  int64
#  14  BMI                      23594 non-null  int64
#  15  AGE                      23594 non-null  int64
#  16  CARDIOTOCOGRAPHY         23594 non-null  int64
#  17  MATERNALEDUCATION        23594 non-null  int64
#  18  SUBSTANCEABUSE           23594 non-null  int64
#  19  SMOKING                  23594 non-null  int64
#  20  ALCOHOL                  23594 non-null  int64
# dtypes: int64(21)
# memory usage: 4.0 MB

# %%
Y_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23594 entries, 4241 to 16578
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TYPEOFBIRTH  23594 non-null  int64
# dtypes: int64(1)
# memory usage: 368.7 KB

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5899 entries, 5779 to 4671
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PARITY                   5899 non-null   int64
#  1   OBSTETRICRISK            5899 non-null   int64
#  2   COMORBIDITY              5899 non-null   int64
#  3   NUMBEROFPREVCESAREAN     5899 non-null   int64
#  4   KGINCREASEDPREGNANCY     5899 non-null   int64
#  5   STARTANTENATALCARRE      5899 non-null   int64
#  6   ART                      5899 non-null   int64
#  7   PREVIOUSTERMPREGNANCIES  5899 non-null   int64
#  8   AMNIOTICLIQUID           5899 non-null   int64
#  9   MISCARRIAGES             5899 non-null   int64
#  10  ANESTHESIA               5899 non-null   int64
#  11  GESTAGIONALAGE           5899 non-null   int64
#  12  HEIGHT                   5899 non-null   int64
#  13  WEIGHT                   5899 non-null   int64
#  14  BMI                      5899 non-null   int64
#  15  AGE                      5899 non-null   int64
#  16  CARDIOTOCOGRAPHY         5899 non-null   int64
#  17  MATERNALEDUCATION        5899 non-null   int64
#  18  SUBSTANCEABUSE           5899 non-null   int64
#  19  SMOKING                  5899 non-null   int64
#  20  ALCOHOL                  5899 non-null   int64
# dtypes: int64(21)
# memory usage: 1013.9 KB

# %%
Y_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5899 entries, 5779 to 4671
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TYPEOFBIRTH  5899 non-null   int64
# dtypes: int64(1)
# memory usage: 92.2 KB

# %%
model = DecisionTreeClassifier(criterion = 'entropy')
model.fit(X_train,Y_train)
y_pred = model.predict(X_test)
print(accuracy_score(Y_test,y_pred))
print(precision_score(Y_test,y_pred,pos_label='positive',average='weighted'))
print(recall_score(Y_test,y_pred,pos_label='positive',average='micro'))

ml_dt_f1 = f1_score(Y_test, y_pred,average='micro')

print(ml_dt_f1)
# Out:
# 0.8289540600101712
# 0.8248158140534461
# 0.8289540600101712
# 0.8289540600101712
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,

# %%
RFC = RandomForestClassifier()
RFC.fit(X_train, Y_train.values.ravel())
y_pred = RFC.predict(X_test)
print(accuracy_score(Y_test,y_pred))
print(precision_score(Y_test,y_pred,pos_label='positive',average='weighted'))
print(recall_score(Y_test,y_pred,pos_label='positive',average='micro'))

ml_rfc_f1 = f1_score(Y_test, y_pred,average='micro')

print(ml_rfc_f1)
# Out:
# 0.9162569927106289
# 0.9147769409396159
# 0.9162569927106289
# 0.9162569927106289
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,

# %%
svc = SVC(gamma = 0.001, C = 1000)
y_pred = svc.fit(X_train, Y_train.values.ravel()).predict(X_test)
print(accuracy_score(Y_test,y_pred))
print(precision_score(Y_test,y_pred,pos_label='positive',average='weighted'))
print(recall_score(Y_test,y_pred,pos_label='positive',average='micro'))

ml_svc_f1 = f1_score(Y_test, y_pred,average='micro')

print(ml_svc_f1)
# Out:
# 0.9128665875572131
# 0.910079352048899
# 0.9128665875572131
# 0.9128665875572131
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,

# %%
K = []
training = []
test = []
scores = {}
  
for k in range(2, 21):
    clf = KNeighborsClassifier(n_neighbors = k)
    clf.fit(X_train, Y_train.values.ravel())
  
    training_score = clf.score(X_train, Y_train)
    test_score = clf.score(X_test, Y_test)
    K.append(k)
  
    training.append(training_score)
    test.append(test_score)
    scores[k] = [training_score, test_score]
for keys, values in scores.items():
    print(keys, ':', values)
# Out:
# 2 : [0.9430787488344494, 0.8320054246482455]
# 3 : [0.9072221751292702, 0.8196304458382777]
# 4 : [0.8812409934729168, 0.7970842515680624]
# 5 : [0.86093922183606, 0.7865739955924733]
# 6 : [0.8373739086208358, 0.7677572469910154]
# 7 : [0.8245740442485378, 0.7577555517884387]
# 8 : [0.8082563363567009, 0.7401254449906763]
# 9 : [0.7965584470628125, 0.7387692829293101]
# 10 : [0.7813427142493854, 0.7263943041193422]
# 11 : [0.7679918623378825, 0.716053568401424]
# 12 : [0.755870136475375, 0.7041871503644686]
# 13 : [0.7472238704755446, 0.69808442108832]
# 14 : [0.7359922014071374, 0.6877436853704018]
# 15 : [0.729295583622955, 0.6823190371249365]
# 16 : [0.7209460032211579, 0.6775724699101543]
# 17 : [0.7150546749173519, 0.671300220376335]
# 18 : [0.7065355598881071, 0.6653670113578573]
# 19 : [0.7000932440450962, 0.6597728428547212]
# 20 : [0.6930575570060185, 0.6531615528055603]

# %%
model = KNeighborsClassifier(n_neighbors=2,weights='distance',p=1)
model.fit(X_train,Y_train.values.ravel())
y_pred = model.predict(X_test)
print(accuracy_score(Y_test,y_pred))
print(precision_score(Y_test,y_pred,pos_label='positive',average='weighted'))
print(recall_score(Y_test,y_pred,pos_label='positive',average='micro'))

ml_knn_f1 = f1_score(Y_test, y_pred,average='micro')

print(ml_knn_f1)
# Out:
# 0.8913375148330226
# 0.8887539547453835
# 0.8913375148330226
# 0.8913375148330226
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,

# %%
estimators = [('rf', RandomForestClassifier()),('svr', make_pipeline(StandardScaler(),LinearSVC())),('dt',DecisionTreeClassifier(criterion = 'entropy')),('knn',KNeighborsClassifier(n_neighbors=2,weights='distance',p=1))]
clf = StackingClassifier(estimators=estimators, final_estimator=LogisticRegression())
clf.fit(X_train, Y_train.values.ravel())
y_pred = clf.predict(X_test)
print(accuracy_score(Y_test,y_pred))
print(precision_score(Y_test,y_pred,pos_label='positive',average='weighted'))
print(recall_score(Y_test,y_pred,pos_label='positive',average='micro'))

ml_sc_f1 = f1_score(Y_test, y_pred,average='micro')

print(ml_sc_f1)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# 0.9474487201220546
# 0.9473069098150044
# 0.9474487201220546
# 0.9474487201220547
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,

# %%
# Import libraries
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))

x1 = ['HIGH','MEDIUM','LOW','HIGH-MEDIUM','HIGH-LOW','MEDIUM-LOW','HIGH-MEDIUM-LOW']

y1 = [h_dt_f1,m_dt_f1,l_dt_f1,hm_dt_f1,hl_dt_f1,ml_dt_f1,all_dt_f1]
plt.plot(x1,y1,label='Decision Tree',marker='o', markersize=5)

y2 = [h_rfc_f1,m_rfc_f1,l_rfc_f1,hm_rfc_f1,hl_rfc_f1,ml_rfc_f1,all_rfc_f1]
plt.plot(x1,y2,label='Random Forest',marker='o', markersize=5)

y3 = [h_knn_f1,m_knn_f1,l_knn_f1,hm_knn_f1,hl_knn_f1,ml_knn_f1,all_knn_f1]
plt.plot(x1,y3,label='K-Nearest Neighbors',marker='o', markersize=5)

y4 = [h_svc_f1,m_svc_f1,l_svc_f1,hm_svc_f1,hl_svc_f1,ml_svc_f1,all_svc_f1]
plt.plot(x1,y4,label='Support Vector Machine',marker='o', markersize=5)

y5 = [h_sc_f1,m_sc_f1,l_sc_f1,hm_sc_f1,hl_sc_f1,ml_sc_f1,all_sc_f1]
plt.plot(x1,y5,label='Stacking Classifier',marker='o', markersize=5)



plt.xlabel('CLASSES')
plt.ylabel('F1 SCORES (%)')
plt.title('performance (f1 scores) of the algorithms')

plt.legend()

plt.show()

# %%
# Import libraries
import matplotlib.pyplot as plt
import numpy as np


# Creating dataset

dt = [h_dt_f1,m_dt_f1,l_dt_f1,hm_dt_f1,hl_dt_f1,ml_dt_f1,all_dt_f1]
rfc = [h_rfc_f1,m_rfc_f1,l_rfc_f1,hm_rfc_f1,hl_rfc_f1,ml_rfc_f1,all_rfc_f1]
knn = [h_knn_f1,m_knn_f1,l_knn_f1,hm_knn_f1,hl_knn_f1,ml_knn_f1,all_knn_f1]
svc = [h_svc_f1,m_svc_f1,l_svc_f1,hm_svc_f1,hl_svc_f1,ml_svc_f1,all_svc_f1]
sc = [h_sc_f1,m_sc_f1,l_sc_f1,hm_sc_f1,hl_sc_f1,ml_sc_f1,all_sc_f1]
data = [dt, rfc, knn, svc, sc]

fig = plt.figure(figsize =(10, 7))

# Creating axes instance
ax = fig.add_axes([0, 0, 1, 1])

ax.set_xticklabels(['DT', 'RFC','KNN', 'SVM','SC'])

# Creating plot
bp = ax.boxplot(data)

# show plot
plt.show()

# %%
print("DT -",dt)

print("RFC -",rfc)

print("KNN -",knn)

print("SVM -",svc)

print("SC -",sc)
# Out:
# DT - [0.456, 0.6893085592445933, 0.7834806254248811, 0.8484338869035106, 0.856467409658899, 0.8289540600101712, 0.8727519511367492]
# RFC - [0.464, 0.720377703320134, 0.8475526852481305, 0.8696657557284002, 0.9157379263762242, 0.9162569927106289, 0.9328130302002036]
# KNN - [0.46, 0.6405726469692354, 0.8223997280761387, 0.8351902459533319, 0.8807835190813914, 0.8913375148330226, 0.9100780454699695]
# SVM - [0.592, 0.5418824246116357, 0.8453433038749151, 0.7458482236703805, 0.9159067882472138, 0.9128665875572131, 0.9294197488971836]
# SC - [0.62, 0.721291501675297, 0.881883072739633, 0.8774437670800925, 0.9436001350894968, 0.9474487201220547, 0.9658975229046488]
